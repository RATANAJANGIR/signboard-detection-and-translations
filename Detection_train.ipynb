# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
#import library
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import os
import numpy as np
import torch
from PIL import Image
import re

# %%
device = torch.device('cuda') if torch.cuda.is_available() else torch.device('cpu')

# %% [markdown]
# COCO is a large image dataset designed for object detection, segmentation, person keypoints detection, stuff segmentation, and caption generation. This package provides Matlab, Python, and Lua APIs that assists in loading, parsing, and visualizing the annotations in COCO.

# %%
# %%shell
#
# # Install pycocotools
# git clone https://github.com/cocodataset/cocoapi.git
# cd cocoapi/PythonAPI
# python setup.py build_ext install
# Out:
# Cloning into 'cocoapi'...
# remote: Enumerating objects: 975, done.
# remote: Total 975 (delta 0), reused 0 (delta 0), pack-reused 975
# Receiving objects: 100% (975/975), 11.72 MiB | 26.98 MiB/s, done.
# Resolving deltas: 100% (576/576), done.
# running build_ext
# cythoning pycocotools/_mask.pyx to pycocotools/_mask.c
# /usr/local/lib/python3.7/dist-packages/Cython/Compiler/Main.py:369: FutureWarning: Cython directive 'language_level' not set, using 2 for now (Py2). This will change in a later release! File: /content/cocoapi/PythonAPI/pycocotools/_mask.pyx
#   tree = Parsing.p_module(s, pxd, full_module_name)
# building 'pycocotools._mask' extension
# creating build
# creating build/common
# creating build/temp.linux-x86_64-3.7
# creating build/temp.linux-x86_64-3.7/pycocotools
# x86_64-linux-gnu-gcc -pthread -Wno-unused-result -Wsign-compare -DNDEBUG -g -fwrapv -O2 -Wall -g -fdebug-prefix-map=/build/python3.7-a56wZI/python3.7-3.7.10=. -fstack-protector-strong -Wformat -Werror=format-security -g -fdebug-prefix-map=/build/python3.7-a56wZI/python3.7-3.7.10=. -fstack-protector-strong -Wformat -Werror=format-security -Wdate-time -D_FORTIFY_SOURCE=2 -fPIC -I/usr/local/lib/python3.7/dist-packages/numpy/core/include -I../common -I/usr/include/python3.7m -c ../common/maskApi.c -o build/temp.linux-x86_64-3.7/../common/maskApi.o -Wno-cpp -Wno-unused-function -std=c99
# ../common/maskApi.c: In function ‘rleDecode’:
# ../common/maskApi.c:46:7: warning: this ‘for’ clause does not guard... [-Wmisleading-indentation]
#        for( k=0; k<R[i].cnts[j]; k++ ) *(M++)=v; v=!v; }}
#        ^~~
# ../common/maskApi.c:46:49: note: ...this statement, but the latter is misleadingly indented as if it were guarded by the ‘for’
#        for( k=0; k<R[i].cnts[j]; k++ ) *(M++)=v; v=!v; }}
#                                                  ^
# ../common/maskApi.c: In function ‘rleFrPoly’:
# ../common/maskApi.c:166:3: warning: this ‘for’ clause does not guard... [-Wmisleading-indentation]
#    for(j=0; j<k; j++) x[j]=(int)(scale*xy[j*2+0]+.5); x[k]=x[0];
#    ^~~
# ../common/maskApi.c:166:54: note: ...this statement, but the latter is misleadingly indented as if it were guarded by the ‘for’
#    for(j=0; j<k; j++) x[j]=(int)(scale*xy[j*2+0]+.5); x[k]=x[0];
#                                                       ^
# ../common/maskApi.c:167:3: warning: this ‘for’ clause does not guard... [-Wmisleading-indentation]
#    for(j=0; j<k; j++) y[j]=(int)(scale*xy[j*2+1]+.5); y[k]=y[0];
#    ^~~
# ../common/maskApi.c:167:54: note: ...this statement, but the latter is misleadingly indented as if it were guarded by the ‘for’
#    for(j=0; j<k; j++) y[j]=(int)(scale*xy[j*2+1]+.5); y[k]=y[0];
#                                                       ^
# ../common/maskApi.c: In function ‘rleToString’:
# ../common/maskApi.c:212:7: warning: this ‘if’ clause does not guard... [-Wmisleading-indentation]
#        if(more) c |= 0x20; c+=48; s[p++]=c;
#        ^~
# ../common/maskApi.c:212:27: note: ...this statement, but the latter is misleadingly indented as if it were guarded by the ‘if’
#        if(more) c |= 0x20; c+=48; s[p++]=c;
#                            ^
# ../common/maskApi.c: In function ‘rleFrString’:
# ../common/maskApi.c:220:3: warning: this ‘while’ clause does not guard... [-Wmisleading-indentation]
#    while( s[m] ) m++; cnts=malloc(sizeof(uint)*m); m=0;
#    ^~~~~
# ../common/maskApi.c:220:22: note: ...this statement, but the latter is misleadingly indented as if it were guarded by the ‘while’
#    while( s[m] ) m++; cnts=malloc(sizeof(uint)*m); m=0;
#                       ^~~~
# ../common/maskApi.c:228:5: warning: this ‘if’ clause does not guard... [-Wmisleading-indentation]
#      if(m>2) x+=(long) cnts[m-2]; cnts[m++]=(uint) x;
#      ^~
# ../common/maskApi.c:228:34: note: ...this statement, but the latter is misleadingly indented as if it were guarded by the ‘if’
#      if(m>2) x+=(long) cnts[m-2]; cnts[m++]=(uint) x;
#                                   ^~~~
# ../common/maskApi.c: In function ‘rleToBbox’:
# ../common/maskApi.c:141:31: warning: ‘xp’ may be used uninitialized in this function [-Wmaybe-uninitialized]
#        if(j%2==0) xp=x; else if(xp<x) { ys=0; ye=h-1; }
#                                ^
# x86_64-linux-gnu-gcc -pthread -Wno-unused-result -Wsign-compare -DNDEBUG -g -fwrapv -O2 -Wall -g -fdebug-prefix-map=/build/python3.7-a56wZI/python3.7-3.7.10=. -fstack-protector-strong -Wformat -Werror=format-security -g -fdebug-prefix-map=/build/python3.7-a56wZI/python3.7-3.7.10=. -fstack-protector-strong -Wformat -Werror=format-security -Wdate-time -D_FORTIFY_SOURCE=2 -fPIC -I/usr/local/lib/python3.7/dist-packages/numpy/core/include -I../common -I/usr/include/python3.7m -c pycocotools/_mask.c -o build/temp.linux-x86_64-3.7/pycocotools/_mask.o -Wno-cpp -Wno-unused-function -std=c99
# creating build/lib.linux-x86_64-3.7
# creating build/lib.linux-x86_64-3.7/pycocotools
# x86_64-linux-gnu-gcc -pthread -shared -Wl,-O1 -Wl,-Bsymbolic-functions -Wl,-Bsymbolic-functions -Wl,-z,relro -Wl,-Bsymbolic-functions -Wl,-z,relro -g -fdebug-prefix-map=/build/python3.7-a56wZI/python3.7-3.7.10=. -fstack-protector-strong -Wformat -Werror=format-security -Wdate-time -D_FORTIFY_SOURCE=2 build/temp.linux-x86_64-3.7/../common/maskApi.o build/temp.linux-x86_64-3.7/pycocotools/_mask.o -o build/lib.linux-x86_64-3.7/pycocotools/_mask.cpython-37m-x86_64-linux-gnu.so
# running install
# running bdist_egg
# running egg_info
# creating pycocotools.egg-info
# writing pycocotools.egg-info/PKG-INFO
# writing dependency_links to pycocotools.egg-info/dependency_links.txt
# writing requirements to pycocotools.egg-info/requires.txt
# writing top-level names to pycocotools.egg-info/top_level.txt
# writing manifest file 'pycocotools.egg-info/SOURCES.txt'
# writing manifest file 'pycocotools.egg-info/SOURCES.txt'
# installing library code to build/bdist.linux-x86_64/egg
# running install_lib
# running build_py
# copying pycocotools/cocoeval.py -> build/lib.linux-x86_64-3.7/pycocotools
# copying pycocotools/coco.py -> build/lib.linux-x86_64-3.7/pycocotools
# copying pycocotools/__init__.py -> build/lib.linux-x86_64-3.7/pycocotools
# copying pycocotools/mask.py -> build/lib.linux-x86_64-3.7/pycocotools
# creating build/bdist.linux-x86_64
# creating build/bdist.linux-x86_64/egg
# creating build/bdist.linux-x86_64/egg/pycocotools
# copying build/lib.linux-x86_64-3.7/pycocotools/cocoeval.py -> build/bdist.linux-x86_64/egg/pycocotools
# copying build/lib.linux-x86_64-3.7/pycocotools/coco.py -> build/bdist.linux-x86_64/egg/pycocotools
# copying build/lib.linux-x86_64-3.7/pycocotools/__init__.py -> build/bdist.linux-x86_64/egg/pycocotools
# copying build/lib.linux-x86_64-3.7/pycocotools/mask.py -> build/bdist.linux-x86_64/egg/pycocotools
# copying build/lib.linux-x86_64-3.7/pycocotools/_mask.cpython-37m-x86_64-linux-gnu.so -> build/bdist.linux-x86_64/egg/pycocotools
# byte-compiling build/bdist.linux-x86_64/egg/pycocotools/cocoeval.py to cocoeval.cpython-37.pyc
# byte-compiling build/bdist.linux-x86_64/egg/pycocotools/coco.py to coco.cpython-37.pyc
# byte-compiling build/bdist.linux-x86_64/egg/pycocotools/__init__.py to __init__.cpython-37.pyc
# byte-compiling build/bdist.linux-x86_64/egg/pycocotools/mask.py to mask.cpython-37.pyc
# creating stub loader for pycocotools/_mask.cpython-37m-x86_64-linux-gnu.so
# byte-compiling build/bdist.linux-x86_64/egg/pycocotools/_mask.py to _mask.cpython-37.pyc
# creating build/bdist.linux-x86_64/egg/EGG-INFO
# copying pycocotools.egg-info/PKG-INFO -> build/bdist.linux-x86_64/egg/EGG-INFO
# copying pycocotools.egg-info/SOURCES.txt -> build/bdist.linux-x86_64/egg/EGG-INFO
# copying pycocotools.egg-info/dependency_links.txt -> build/bdist.linux-x86_64/egg/EGG-INFO
# copying pycocotools.egg-info/requires.txt -> build/bdist.linux-x86_64/egg/EGG-INFO
# copying pycocotools.egg-info/top_level.txt -> build/bdist.linux-x86_64/egg/EGG-INFO
# writing build/bdist.linux-x86_64/egg/EGG-INFO/native_libs.txt
# zip_safe flag not set; analyzing archive contents...
# pycocotools.__pycache__._mask.cpython-37: module references __file__
# creating dist
# creating 'dist/pycocotools-2.0-py3.7-linux-x86_64.egg' and adding 'build/bdist.linux-x86_64/egg' to it
# removing 'build/bdist.linux-x86_64/egg' (and everything under it)
# Processing pycocotools-2.0-py3.7-linux-x86_64.egg
# creating /usr/local/lib/python3.7/dist-packages/pycocotools-2.0-py3.7-linux-x86_64.egg
# Extracting pycocotools-2.0-py3.7-linux-x86_64.egg to /usr/local/lib/python3.7/dist-packages
# Adding pycocotools 2.0 to easy-install.pth file
#
# Installed /usr/local/lib/python3.7/dist-packages/pycocotools-2.0-py3.7-linux-x86_64.egg
# Processing dependencies for pycocotools==2.0
# Searching for matplotlib==3.2.2
# Best match: matplotlib 3.2.2
# Adding matplotlib 3.2.2 to easy-install.pth file
#
# Using /usr/local/lib/python3.7/dist-packages
# Searching for Cython==0.29.22
# Best match: Cython 0.29.22
# Adding Cython 0.29.22 to easy-install.pth file
# Installing cygdb script to /usr/local/bin
# Installing cython script to /usr/local/bin
# Installing cythonize script to /usr/local/bin
#
# Using /usr/local/lib/python3.7/dist-packages
# Searching for setuptools==56.0.0
# Best match: setuptools 56.0.0
# Adding setuptools 56.0.0 to easy-install.pth file
#
# Using /usr/local/lib/python3.7/dist-packages
# Searching for numpy==1.19.5
# Best match: numpy 1.19.5
# Adding numpy 1.19.5 to easy-install.pth file
# Installing f2py script to /usr/local/bin
# Installing f2py3 script to /usr/local/bin
# Installing f2py3.7 script to /usr/local/bin
#
# Using /usr/local/lib/python3.7/dist-packages
# Searching for kiwisolver==1.3.1
# Best match: kiwisolver 1.3.1
# Adding kiwisolver 1.3.1 to easy-install.pth file
#
# Using /usr/local/lib/python3.7/dist-packages
# Searching for pyparsing==2.4.7
# Best match: pyparsing 2.4.7
# Adding pyparsing 2.4.7 to easy-install.pth file
#
# Using /usr/local/lib/python3.7/dist-packages
# Searching for cycler==0.10.0
# Best match: cycler 0.10.0
# Adding cycler 0.10.0 to easy-install.pth file
#
# Using /usr/local/lib/python3.7/dist-packages
# Searching for python-dateutil==2.8.1
# Best match: python-dateutil 2.8.1
# Adding python-dateutil 2.8.1 to easy-install.pth file
#
# Using /usr/local/lib/python3.7/dist-packages
# Searching for six==1.15.0
# Best match: six 1.15.0
# Adding six 1.15.0 to easy-install.pth file
#
# Using /usr/local/lib/python3.7/dist-packages
# Finished processing dependencies for pycocotools==2.0

# %%
# %%shell
#
# # Download TorchVision repo to use some files from
# # references/detection
# git clone https://github.com/pytorch/vision.git
# cd vision
# git checkout v0.3.0
#
# cp references/detection/utils.py ../
# cp references/detection/transforms.py ../
# cp references/detection/coco_eval.py ../
# cp references/detection/engine.py ../
# cp references/detection/coco_utils.py ../
# Out:
# Cloning into 'vision'...
# remote: Enumerating objects: 22445, done.
# remote: Counting objects: 100% (3226/3226), done.
# remote: Compressing objects: 100% (798/798), done.
# remote: Total 22445 (delta 2471), reused 3044 (delta 2348), pack-reused 19219
# Receiving objects: 100% (22445/22445), 27.08 MiB | 17.70 MiB/s, done.
# Resolving deltas: 100% (16532/16532), done.
# Note: checking out 'v0.3.0'.
#
# You are in 'detached HEAD' state. You can look around, make experimental
# changes and commit them, and you can discard any commits you make in this
# state without impacting any branches by performing another checkout.
#
# If you want to create a new branch to retain commits you create, you may
# do so (now or later) by using -b with the checkout command again. Example:
#
#   git checkout -b <new-branch-name>
#
# HEAD is now at be376084 version check against PyTorch's CUDA version

# %%
from engine import train_one_epoch, evaluate
import utils
import transforms as T

from torch.utils.data import Dataset
import torchvision
from torchvision.models.detection.faster_rcnn import FastRCNNPredictor
from torchvision.models.detection.mask_rcnn import MaskRCNNPredictor

# %% [markdown]
# Fasterrcnn expects our data in the form of an image and a dictionary corresponding to it. The dictionary should include bounding boxes and labels at the very least.
#
# We convert our boxes to the (xmin, ymin, xmax, ymax) format. We assign our labels to all as either 0,1 or 2, accordingly. Finally, we convert everything to PyTorch tensors.

# %%
class DetectionDataset(Dataset):

  def __init__(self,root,transforms = None):

    self.root = root
    self.transforms = transforms

    self.images = list(sorted(os.listdir(os.path.join(root,'Image'))))
    self.masks = list(sorted(os.listdir(os.path.join(root,'Annotation'))))

  def __len__(self):
        return len(self.images)
        

  def __getitem__(self,index):

      img_path = os.path.join(self.root,'Image',self.images[index])
      mask_path = os.path.join(self.root,'Annotation',self.masks[index])
      image = Image.open(img_path)   
      f = open(mask_path,'r')
      mask = f.readlines()
      f.close()
      coordinates_pattern = re.compile(r'(\d+)')
      label_pattern = re.compile(r'([A-Z]+)')
      boxes = []
      labels = []
      num_boxes = len(mask)
      # store the bounding box coordinates of corresponding images from annotation file
      for box in mask:
        coordinates = coordinates_pattern.findall(box)
        xmin = min(int(coordinates[0]),int(coordinates[2]))
        xmax = max(int(coordinates[0]),int(coordinates[2]))
        ymin = min(int(coordinates[4]),int(coordinates[6]))
        ymax = max(int(coordinates[4]),int(coordinates[6]))

        boxes.append([xmin, ymin, xmax, ymax])

        label = label_pattern.findall(box)
        if label[0] == 'HINDI':
          labels.append(1)
        elif label[0] == 'ENGLISH':
          labels.append(2) 
        else:
          labels.append(0)
      
      boxes = torch.as_tensor(boxes, dtype=torch.float32)
      labels = torch.as_tensor(labels, dtype=torch.int64)
      iscrowd = torch.zeros(num_boxes, dtype=torch.int64)
      image_id = torch.tensor([index])
      #calculating area of the bounding boxes
      area = (boxes[:, 3] - boxes[:, 1]) * (boxes[:, 2] - boxes[:, 0])
      target = {}

      target["boxes"] = boxes
      target["labels"] = labels
      target["image_id"] = image_id
      target["area"] = area
      target["iscrowd"] = iscrowd
      if self.transforms is not None:
          image, target = self.transforms(image, target)

      return image, target

# %%
data_path = '/content/drive/MyDrive/EE626_Project/real_Image_dataset_Detection'

# %%
data = DetectionDataset(data_path)

# %% [markdown]
# We will now define our model. We are using a ResNet50 backbone with a feature pyramid network for our Fasterrcnn. The backbone is easily customizable. The only parameter we need to pass is the number of classes in our dataset.  In train mode, the model takes images and target dictionary as input and produces a loss_dict as output.

# %%
def get_detection_model(num_classes):
  # load a model; pre-trained on COCO
    model = torchvision.models.detection.fasterrcnn_resnet50_fpn(pretrained=True)
    # get number of input features for the classifier
    in_features = model.roi_heads.box_predictor.cls_score.in_features
    # replace the pre-trained head with a new one
    model.roi_heads.box_predictor = FastRCNNPredictor(in_features, num_classes)  # Using pytorch FasterRCNN for detection 
    return model

# %%
def get_transform(train):

    transforms = []
    transforms.append(T.ToTensor())

    if train:
        transforms.append(T.RandomHorizontalFlip(0.5))  # performing random flips to images, to make it train efficiently
        
    return T.Compose(transforms)

# %%
dataset_train = DetectionDataset(data_path, get_transform(train=True))
dataset_test = DetectionDataset(data_path, get_transform(train=False))

# %%
torch.manual_seed(42)
indices = torch.randperm(len(dataset_train)).tolist()
dataset_train = torch.utils.data.Subset(dataset_train, indices[:-50])
dataset_test = torch.utils.data.Subset(dataset_test, indices[-50:])

# %%
data_loader_train = torch.utils.data.DataLoader(
    dataset_train, batch_size=2, shuffle=True, num_workers=4,
    collate_fn=utils.collate_fn)

data_loader_test = torch.utils.data.DataLoader(
    dataset_test, batch_size=2, shuffle=False, num_workers=4,
    collate_fn=utils.collate_fn)
# Out:
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:477: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))

# %%
device = torch.device('cuda') if torch.cuda.is_available() else torch.device('cpu')

# %%
num_classes = 3     #ENGLISH, HINDI, OTHER

model = get_detection_model(num_classes)
model.to(device)
# Out:
# Downloading: "https://download.pytorch.org/models/fasterrcnn_resnet50_fpn_coco-258fb6c6.pth" to /root/.cache/torch/hub/checkpoints/fasterrcnn_resnet50_fpn_coco-258fb6c6.pth
# HBox(children=(FloatProgress(value=0.0, max=167502836.0), HTML(value='')))
# FasterRCNN(
#   (transform): GeneralizedRCNNTransform(
#       Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
#       Resize(min_size=(800,), max_size=1333, mode='bilinear')
#   )
#   (backbone): BackboneWithFPN(
#     (body): IntermediateLayerGetter(
#       (conv1): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#       (bn1): FrozenBatchNorm2d(64, eps=0.0)
#       (relu): ReLU(inplace=True)
#       (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#       (layer1): Sequential(
#         (0): Bottleneck(
#           (conv1): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): FrozenBatchNorm2d(64, eps=0.0)
#           (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): FrozenBatchNorm2d(64, eps=0.0)
#           (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): FrozenBatchNorm2d(256, eps=0.0)
#           (relu): ReLU(inplace=True)
#           (downsample): Sequential(
#             (0): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): FrozenBatchNorm2d(256, eps=0.0)
#           )
#         )
#         (1): Bottleneck(
#           (conv1): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): FrozenBatchNorm2d(64, eps=0.0)
#           (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): FrozenBatchNorm2d(64, eps=0.0)
#           (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): FrozenBatchNorm2d(256, eps=0.0)
#           (relu): ReLU(inplace=True)
#         )
#         (2): Bottleneck(
#           (conv1): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): FrozenBatchNorm2d(64, eps=0.0)
#           (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): FrozenBatchNorm2d(64, eps=0.0)
#           (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): FrozenBatchNorm2d(256, eps=0.0)
#           (relu): ReLU(inplace=True)
#         )
#       )
#       (layer2): Sequential(
#         (0): Bottleneck(
#           (conv1): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): FrozenBatchNorm2d(128, eps=0.0)
#           (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#           (bn2): FrozenBatchNorm2d(128, eps=0.0)
#           (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): FrozenBatchNorm2d(512, eps=0.0)
#           (relu): ReLU(inplace=True)
#           (downsample): Sequential(
#             (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#             (1): FrozenBatchNorm2d(512, eps=0.0)
#           )
#         )
#         (1): Bottleneck(
#           (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): FrozenBatchNorm2d(128, eps=0.0)
#           (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): FrozenBatchNorm2d(128, eps=0.0)
#           (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): FrozenBatchNorm2d(512, eps=0.0)
#           (relu): ReLU(inplace=True)
#         )
#         (2): Bottleneck(
#           (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): FrozenBatchNorm2d(128, eps=0.0)
#           (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): FrozenBatchNorm2d(128, eps=0.0)
#           (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): FrozenBatchNorm2d(512, eps=0.0)
#           (relu): ReLU(inplace=True)
#         )
#         (3): Bottleneck(
#           (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): FrozenBatchNorm2d(128, eps=0.0)
#           (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): FrozenBatchNorm2d(128, eps=0.0)
#           (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): FrozenBatchNorm2d(512, eps=0.0)
#           (relu): ReLU(inplace=True)
#         )
#       )
#       (layer3): Sequential(
#         (0): Bottleneck(
#           (conv1): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): FrozenBatchNorm2d(256, eps=0.0)
#           (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#           (bn2): FrozenBatchNorm2d(256, eps=0.0)
#           (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): FrozenBatchNorm2d(1024, eps=0.0)
#           (relu): ReLU(inplace=True)
#           (downsample): Sequential(
#             (0): Conv2d(512, 1024, kernel_size=(1, 1), stride=(2, 2), bias=False)
#             (1): FrozenBatchNorm2d(1024, eps=0.0)
#           )
#         )
#         (1): Bottleneck(
#           (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): FrozenBatchNorm2d(256, eps=0.0)
#           (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): FrozenBatchNorm2d(256, eps=0.0)
#           (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): FrozenBatchNorm2d(1024, eps=0.0)
#           (relu): ReLU(inplace=True)
#         )
#         (2): Bottleneck(
#           (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): FrozenBatchNorm2d(256, eps=0.0)
#           (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): FrozenBatchNorm2d(256, eps=0.0)
#           (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): FrozenBatchNorm2d(1024, eps=0.0)
#           (relu): ReLU(inplace=True)
#         )
#         (3): Bottleneck(
#           (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): FrozenBatchNorm2d(256, eps=0.0)
#           (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): FrozenBatchNorm2d(256, eps=0.0)
#           (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): FrozenBatchNorm2d(1024, eps=0.0)
#           (relu): ReLU(inplace=True)
#         )
#         (4): Bottleneck(
#           (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): FrozenBatchNorm2d(256, eps=0.0)
#           (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): FrozenBatchNorm2d(256, eps=0.0)
#           (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): FrozenBatchNorm2d(1024, eps=0.0)
#           (relu): ReLU(inplace=True)
#         )
#         (5): Bottleneck(
#           (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): FrozenBatchNorm2d(256, eps=0.0)
#           (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): FrozenBatchNorm2d(256, eps=0.0)
#           (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): FrozenBatchNorm2d(1024, eps=0.0)
#           (relu): ReLU(inplace=True)
#         )
#       )
#       (layer4): Sequential(
#         (0): Bottleneck(
#           (conv1): Conv2d(1024, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): FrozenBatchNorm2d(512, eps=0.0)
#           (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#           (bn2): FrozenBatchNorm2d(512, eps=0.0)
#           (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): FrozenBatchNorm2d(2048, eps=0.0)
#           (relu): ReLU(inplace=True)
#           (downsample): Sequential(
#             (0): Conv2d(1024, 2048, kernel_size=(1, 1), stride=(2, 2), bias=False)
#             (1): FrozenBatchNorm2d(2048, eps=0.0)
#           )
#         )
#         (1): Bottleneck(
#           (conv1): Conv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): FrozenBatchNorm2d(512, eps=0.0)
#           (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): FrozenBatchNorm2d(512, eps=0.0)
#           (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): FrozenBatchNorm2d(2048, eps=0.0)
#           (relu): ReLU(inplace=True)
#         )
#         (2): Bottleneck(
#           (conv1): Conv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): FrozenBatchNorm2d(512, eps=0.0)
#           (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): FrozenBatchNorm2d(512, eps=0.0)
#           (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): FrozenBatchNorm2d(2048, eps=0.0)
#           (relu): ReLU(inplace=True)
#         )
#       )
#     )
#     (fpn): FeaturePyramidNetwork(
#       (inner_blocks): ModuleList(
#         (0): Conv2d(256, 256, kernel_size=(1, 1), stride=(1, 1))
#         (1): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1))
#         (2): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1))
#         (3): Conv2d(2048, 256, kernel_size=(1, 1), stride=(1, 1))
#       )
#       (layer_blocks): ModuleList(
#         (0): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (3): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       )
#       (extra_blocks): LastLevelMaxPool()
#     )
#   )
#   (rpn): RegionProposalNetwork(
#     (anchor_generator): AnchorGenerator()
#     (head): RPNHead(
#       (conv): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (cls_logits): Conv2d(256, 3, kernel_size=(1, 1), stride=(1, 1))
#       (bbox_pred): Conv2d(256, 12, kernel_size=(1, 1), stride=(1, 1))
#     )
#   )
#   (roi_heads): RoIHeads(
#     (box_roi_pool): MultiScaleRoIAlign(featmap_names=['0', '1', '2', '3'], output_size=(7, 7), sampling_ratio=2)
#     (box_head): TwoMLPHead(
#       (fc6): Linear(in_features=12544, out_features=1024, bias=True)
#       (fc7): Linear(in_features=1024, out_features=1024, bias=True)
#     )
#     (box_predictor): FastRCNNPredictor(
#       (cls_score): Linear(in_features=1024, out_features=3, bias=True)
#       (bbox_pred): Linear(in_features=1024, out_features=12, bias=True)
#     )
#   )
# )

# %%
params = [p for p in model.parameters() if p.requires_grad]
optimizer = torch.optim.SGD(params, lr=0.005,
                            momentum=0.9, weight_decay=0.0005) # Optimizer for training

lr_scheduler = torch.optim.lr_scheduler.StepLR(optimizer,
                                               step_size=3,
                                               gamma=0.1)

# %%
num_epochs = 10

for epoch in range(num_epochs):

    train_one_epoch(model, optimizer, data_loader_train, device, epoch, print_freq=5)

    lr_scheduler.step()
    
    evaluate(model, data_loader_test, device=device)
# Out:
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:477: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# Epoch: [0]  [  0/189]  eta: 0:07:30  lr: 0.000032  loss: 2.1829 (2.1829)  loss_classifier: 0.9275 (0.9275)  loss_box_reg: 0.2722 (0.2722)  loss_objectness: 0.9246 (0.9246)  loss_rpn_box_reg: 0.0586 (0.0586)  time: 2.3841  data: 1.4334  max mem: 2225
# Epoch: [0]  [  5/189]  eta: 0:02:39  lr: 0.000164  loss: 1.9798 (3.0540)  loss_classifier: 0.8792 (0.8900)  loss_box_reg: 0.2722 (0.2621)  loss_objectness: 0.9246 (1.6643)  loss_rpn_box_reg: 0.0542 (0.2377)  time: 0.8660  data: 0.2474  max mem: 2913
# Epoch: [0]  [ 10/189]  eta: 0:02:10  lr: 0.000297  loss: 1.5073 (2.3849)  loss_classifier: 0.7622 (0.7477)  loss_box_reg: 0.2722 (0.2592)  loss_objectness: 0.5913 (1.1916)  loss_rpn_box_reg: 0.0586 (0.1864)  time: 0.7265  data: 0.1375  max mem: 2913
# Epoch: [0]  [ 15/189]  eta: 0:01:55  lr: 0.000430  loss: 1.3456 (1.9595)  loss_classifier: 0.5431 (0.6441)  loss_box_reg: 0.3180 (0.3168)  loss_objectness: 0.2663 (0.8486)  loss_rpn_box_reg: 0.0508 (0.1500)  time: 0.6651  data: 0.0970  max mem: 2913
# Epoch: [0]  [ 20/189]  eta: 0:01:47  lr: 0.000563  loss: 1.2361 (1.7261)  loss_classifier: 0.4857 (0.5732)  loss_box_reg: 0.3180 (0.3225)  loss_objectness: 0.1717 (0.6740)  loss_rpn_box_reg: 0.0508 (0.1564)  time: 0.5470  data: 0.0082  max mem: 2913
# Epoch: [0]  [ 25/189]  eta: 0:01:41  lr: 0.000696  loss: 1.0782 (1.6193)  loss_classifier: 0.4342 (0.5465)  loss_box_reg: 0.3238 (0.3549)  loss_objectness: 0.1138 (0.5729)  loss_rpn_box_reg: 0.0459 (0.1450)  time: 0.5412  data: 0.0075  max mem: 2918
# Epoch: [0]  [ 30/189]  eta: 0:01:36  lr: 0.000829  loss: 0.9834 (1.4721)  loss_classifier: 0.3559 (0.4966)  loss_box_reg: 0.3500 (0.3509)  loss_objectness: 0.0911 (0.4939)  loss_rpn_box_reg: 0.0404 (0.1305)  time: 0.5373  data: 0.0081  max mem: 2918
# Epoch: [0]  [ 35/189]  eta: 0:01:32  lr: 0.000961  loss: 0.7538 (1.3678)  loss_classifier: 0.2620 (0.4599)  loss_box_reg: 0.3500 (0.3549)  loss_objectness: 0.0804 (0.4332)  loss_rpn_box_reg: 0.0468 (0.1199)  time: 0.5457  data: 0.0080  max mem: 2918
# Epoch: [0]  [ 40/189]  eta: 0:01:28  lr: 0.001094  loss: 0.7420 (1.2910)  loss_classifier: 0.2604 (0.4341)  loss_box_reg: 0.3859 (0.3623)  loss_objectness: 0.0574 (0.3852)  loss_rpn_box_reg: 0.0436 (0.1094)  time: 0.5526  data: 0.0079  max mem: 2918
# Epoch: [0]  [ 45/189]  eta: 0:01:24  lr: 0.001227  loss: 0.6631 (1.2249)  loss_classifier: 0.2210 (0.4110)  loss_box_reg: 0.3682 (0.3660)  loss_objectness: 0.0468 (0.3463)  loss_rpn_box_reg: 0.0436 (0.1016)  time: 0.5503  data: 0.0078  max mem: 2918
# Epoch: [0]  [ 50/189]  eta: 0:01:21  lr: 0.001360  loss: 0.6631 (1.1725)  loss_classifier: 0.2224 (0.3967)  loss_box_reg: 0.3682 (0.3648)  loss_objectness: 0.0340 (0.3142)  loss_rpn_box_reg: 0.0404 (0.0969)  time: 0.5522  data: 0.0077  max mem: 2918
# Epoch: [0]  [ 55/189]  eta: 0:01:18  lr: 0.001493  loss: 0.6110 (1.1311)  loss_classifier: 0.2203 (0.3802)  loss_box_reg: 0.3225 (0.3695)  loss_objectness: 0.0196 (0.2916)  loss_rpn_box_reg: 0.0233 (0.0898)  time: 0.5614  data: 0.0076  max mem: 3206
# Epoch: [0]  [ 60/189]  eta: 0:01:15  lr: 0.001626  loss: 0.6417 (1.1044)  loss_classifier: 0.2203 (0.3721)  loss_box_reg: 0.3861 (0.3775)  loss_objectness: 0.0184 (0.2701)  loss_rpn_box_reg: 0.0207 (0.0846)  time: 0.5600  data: 0.0072  max mem: 3206
# Epoch: [0]  [ 65/189]  eta: 0:01:11  lr: 0.001759  loss: 0.6486 (1.1042)  loss_classifier: 0.2203 (0.3625)  loss_box_reg: 0.3861 (0.3726)  loss_objectness: 0.0196 (0.2768)  loss_rpn_box_reg: 0.0295 (0.0923)  time: 0.5643  data: 0.0076  max mem: 3206
# Epoch: [0]  [ 70/189]  eta: 0:01:09  lr: 0.001891  loss: 0.6486 (1.0838)  loss_classifier: 0.2105 (0.3517)  loss_box_reg: 0.3861 (0.3691)  loss_objectness: 0.0217 (0.2694)  loss_rpn_box_reg: 0.0309 (0.0936)  time: 0.5700  data: 0.0074  max mem: 3206
# Epoch: [0]  [ 75/189]  eta: 0:01:06  lr: 0.002024  loss: 0.7248 (1.0601)  loss_classifier: 0.2130 (0.3420)  loss_box_reg: 0.3747 (0.3643)  loss_objectness: 0.0338 (0.2579)  loss_rpn_box_reg: 0.0404 (0.0959)  time: 0.5687  data: 0.0076  max mem: 3206
# Epoch: [0]  [ 80/189]  eta: 0:01:03  lr: 0.002157  loss: 0.6486 (1.0367)  loss_classifier: 0.2001 (0.3361)  loss_box_reg: 0.2855 (0.3615)  loss_objectness: 0.0526 (0.2452)  loss_rpn_box_reg: 0.0567 (0.0939)  time: 0.5870  data: 0.0082  max mem: 3206
# Epoch: [0]  [ 85/189]  eta: 0:01:00  lr: 0.002290  loss: 0.5261 (1.0030)  loss_classifier: 0.1901 (0.3248)  loss_box_reg: 0.2245 (0.3520)  loss_objectness: 0.0439 (0.2336)  loss_rpn_box_reg: 0.0418 (0.0925)  time: 0.5945  data: 0.0081  max mem: 3206
# Epoch: [0]  [ 90/189]  eta: 0:00:57  lr: 0.002423  loss: 0.5925 (0.9957)  loss_classifier: 0.2027 (0.3245)  loss_box_reg: 0.2855 (0.3565)  loss_objectness: 0.0439 (0.2236)  loss_rpn_box_reg: 0.0479 (0.0911)  time: 0.5950  data: 0.0086  max mem: 3206
# Epoch: [0]  [ 95/189]  eta: 0:00:54  lr: 0.002556  loss: 0.5028 (0.9734)  loss_classifier: 0.1901 (0.3190)  loss_box_reg: 0.2503 (0.3533)  loss_objectness: 0.0346 (0.2133)  loss_rpn_box_reg: 0.0330 (0.0878)  time: 0.5894  data: 0.0085  max mem: 3206
# Epoch: [0]  [100/189]  eta: 0:00:51  lr: 0.002688  loss: 0.5505 (0.9584)  loss_classifier: 0.2111 (0.3157)  loss_box_reg: 0.3056 (0.3541)  loss_objectness: 0.0255 (0.2037)  loss_rpn_box_reg: 0.0287 (0.0850)  time: 0.5796  data: 0.0079  max mem: 3206
# Epoch: [0]  [105/189]  eta: 0:00:49  lr: 0.002821  loss: 0.6394 (0.9465)  loss_classifier: 0.2191 (0.3127)  loss_box_reg: 0.3620 (0.3547)  loss_objectness: 0.0224 (0.1958)  loss_rpn_box_reg: 0.0277 (0.0832)  time: 0.5822  data: 0.0075  max mem: 3206
# Epoch: [0]  [110/189]  eta: 0:00:46  lr: 0.002954  loss: 0.5831 (0.9331)  loss_classifier: 0.2191 (0.3100)  loss_box_reg: 0.3294 (0.3543)  loss_objectness: 0.0184 (0.1878)  loss_rpn_box_reg: 0.0264 (0.0810)  time: 0.5835  data: 0.0071  max mem: 3206
# Epoch: [0]  [115/189]  eta: 0:00:43  lr: 0.003087  loss: 0.5998 (0.9190)  loss_classifier: 0.2203 (0.3060)  loss_box_reg: 0.3341 (0.3537)  loss_objectness: 0.0191 (0.1806)  loss_rpn_box_reg: 0.0248 (0.0786)  time: 0.5857  data: 0.0070  max mem: 3206
# Epoch: [0]  [120/189]  eta: 0:00:40  lr: 0.003220  loss: 0.5831 (0.9025)  loss_classifier: 0.2203 (0.3017)  loss_box_reg: 0.3294 (0.3506)  loss_objectness: 0.0184 (0.1738)  loss_rpn_box_reg: 0.0259 (0.0765)  time: 0.5885  data: 0.0070  max mem: 3206
# Epoch: [0]  [125/189]  eta: 0:00:37  lr: 0.003353  loss: 0.5781 (0.8953)  loss_classifier: 0.2203 (0.3001)  loss_box_reg: 0.2919 (0.3506)  loss_objectness: 0.0164 (0.1693)  loss_rpn_box_reg: 0.0259 (0.0754)  time: 0.5987  data: 0.0074  max mem: 3206
# Epoch: [0]  [130/189]  eta: 0:00:34  lr: 0.003486  loss: 0.5258 (0.8843)  loss_classifier: 0.2091 (0.2973)  loss_box_reg: 0.2919 (0.3495)  loss_objectness: 0.0088 (0.1634)  loss_rpn_box_reg: 0.0262 (0.0741)  time: 0.6098  data: 0.0077  max mem: 3206
# Epoch: [0]  [135/189]  eta: 0:00:31  lr: 0.003618  loss: 0.5153 (0.8843)  loss_classifier: 0.1822 (0.2912)  loss_box_reg: 0.2721 (0.3446)  loss_objectness: 0.0086 (0.1695)  loss_rpn_box_reg: 0.0268 (0.0790)  time: 0.6162  data: 0.0078  max mem: 3206
# Epoch: [0]  [140/189]  eta: 0:00:28  lr: 0.003751  loss: 0.5420 (0.8725)  loss_classifier: 0.1805 (0.2864)  loss_box_reg: 0.2689 (0.3403)  loss_objectness: 0.0227 (0.1674)  loss_rpn_box_reg: 0.0280 (0.0783)  time: 0.6147  data: 0.0078  max mem: 3206
# Epoch: [0]  [145/189]  eta: 0:00:25  lr: 0.003884  loss: 0.5491 (0.8633)  loss_classifier: 0.1595 (0.2831)  loss_box_reg: 0.2643 (0.3396)  loss_objectness: 0.0344 (0.1637)  loss_rpn_box_reg: 0.0268 (0.0769)  time: 0.6031  data: 0.0075  max mem: 3206
# Epoch: [0]  [150/189]  eta: 0:00:22  lr: 0.004017  loss: 0.5564 (0.8573)  loss_classifier: 0.1595 (0.2816)  loss_box_reg: 0.2643 (0.3378)  loss_objectness: 0.0418 (0.1603)  loss_rpn_box_reg: 0.0328 (0.0776)  time: 0.6035  data: 0.0072  max mem: 3206
# Epoch: [0]  [155/189]  eta: 0:00:20  lr: 0.004150  loss: 0.5905 (0.8569)  loss_classifier: 0.1955 (0.2807)  loss_box_reg: 0.2821 (0.3360)  loss_objectness: 0.0540 (0.1595)  loss_rpn_box_reg: 0.0438 (0.0807)  time: 0.6048  data: 0.0075  max mem: 3206
# Epoch: [0]  [160/189]  eta: 0:00:17  lr: 0.004283  loss: 0.5878 (0.8477)  loss_classifier: 0.1946 (0.2772)  loss_box_reg: 0.2821 (0.3340)  loss_objectness: 0.0419 (0.1562)  loss_rpn_box_reg: 0.0476 (0.0804)  time: 0.6061  data: 0.0075  max mem: 3288
# Epoch: [0]  [165/189]  eta: 0:00:14  lr: 0.004415  loss: 0.5740 (0.8346)  loss_classifier: 0.1914 (0.2728)  loss_box_reg: 0.2719 (0.3297)  loss_objectness: 0.0419 (0.1533)  loss_rpn_box_reg: 0.0381 (0.0787)  time: 0.6036  data: 0.0080  max mem: 3288
# Epoch: [0]  [170/189]  eta: 0:00:11  lr: 0.004548  loss: 0.5564 (0.8274)  loss_classifier: 0.1824 (0.2706)  loss_box_reg: 0.2399 (0.3291)  loss_objectness: 0.0419 (0.1499)  loss_rpn_box_reg: 0.0381 (0.0777)  time: 0.5933  data: 0.0088  max mem: 3288
# Epoch: [0]  [175/189]  eta: 0:00:08  lr: 0.004681  loss: 0.4749 (0.8171)  loss_classifier: 0.1556 (0.2677)  loss_box_reg: 0.2378 (0.3268)  loss_objectness: 0.0333 (0.1460)  loss_rpn_box_reg: 0.0262 (0.0765)  time: 0.5935  data: 0.0087  max mem: 3288
# Epoch: [0]  [180/189]  eta: 0:00:05  lr: 0.004814  loss: 0.4493 (0.8077)  loss_classifier: 0.1556 (0.2648)  loss_box_reg: 0.2378 (0.3234)  loss_objectness: 0.0281 (0.1430)  loss_rpn_box_reg: 0.0247 (0.0766)  time: 0.5899  data: 0.0089  max mem: 3288
# Epoch: [0]  [185/189]  eta: 0:00:02  lr: 0.004947  loss: 0.4493 (0.7993)  loss_classifier: 0.1556 (0.2618)  loss_box_reg: 0.2378 (0.3206)  loss_objectness: 0.0221 (0.1401)  loss_rpn_box_reg: 0.0247 (0.0769)  time: 0.5861  data: 0.0085  max mem: 3288
# Epoch: [0]  [188/189]  eta: 0:00:00  lr: 0.005000  loss: 0.4528 (0.7938)  loss_classifier: 0.1378 (0.2600)  loss_box_reg: 0.1961 (0.3186)  loss_objectness: 0.0216 (0.1382)  loss_rpn_box_reg: 0.0247 (0.0770)  time: 0.5881  data: 0.0083  max mem: 3288
# Epoch: [0] Total time: 0:01:51 (0.5902 s / it)
# creating index...
# index created!
# Test:  [ 0/25]  eta: 0:00:14  model_time: 0.3166 (0.3166)  evaluator_time: 0.0087 (0.0087)  time: 0.5930  data: 0.2635  max mem: 3288
# Test:  [24/25]  eta: 0:00:00  model_time: 0.2329 (0.2447)  evaluator_time: 0.0071 (0.0104)  time: 0.2599  data: 0.0058  max mem: 3288
# Test: Total time: 0:00:06 (0.2780 s / it)
# Averaged stats: model_time: 0.2329 (0.2447)  evaluator_time: 0.0071 (0.0104)
# Accumulating evaluation results...
# DONE (t=0.03s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.268
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.532
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.211
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.064
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.323
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.232
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.105
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.421
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.488
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.146
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.508
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.504
# Epoch: [1]  [  0/189]  eta: 0:02:36  lr: 0.005000  loss: 0.9697 (0.9697)  loss_classifier: 0.3221 (0.3221)  loss_box_reg: 0.3433 (0.3433)  loss_objectness: 0.0977 (0.0977)  loss_rpn_box_reg: 0.2066 (0.2066)  time: 0.8275  data: 0.2760  max mem: 3288
# Epoch: [1]  [  5/189]  eta: 0:01:55  lr: 0.005000  loss: 0.4949 (0.5545)  loss_classifier: 0.1844 (0.1995)  loss_box_reg: 0.2177 (0.2457)  loss_objectness: 0.0177 (0.0286)  loss_rpn_box_reg: 0.0575 (0.0807)  time: 0.6257  data: 0.0523  max mem: 3288
# Epoch: [1]  [ 10/189]  eta: 0:01:47  lr: 0.005000  loss: 0.4539 (0.5129)  loss_classifier: 0.1730 (0.1924)  loss_box_reg: 0.2469 (0.2434)  loss_objectness: 0.0140 (0.0205)  loss_rpn_box_reg: 0.0409 (0.0566)  time: 0.6008  data: 0.0307  max mem: 3288
# Epoch: [1]  [ 15/189]  eta: 0:01:43  lr: 0.005000  loss: 0.4949 (0.5306)  loss_classifier: 0.1844 (0.1911)  loss_box_reg: 0.2603 (0.2648)  loss_objectness: 0.0125 (0.0195)  loss_rpn_box_reg: 0.0350 (0.0552)  time: 0.5970  data: 0.0233  max mem: 3288
# Epoch: [1]  [ 20/189]  eta: 0:01:42  lr: 0.005000  loss: 0.5459 (0.5530)  loss_classifier: 0.1876 (0.2045)  loss_box_reg: 0.2607 (0.2780)  loss_objectness: 0.0124 (0.0176)  loss_rpn_box_reg: 0.0350 (0.0529)  time: 0.5958  data: 0.0065  max mem: 3288
# Epoch: [1]  [ 25/189]  eta: 0:01:38  lr: 0.005000  loss: 0.4539 (0.5204)  loss_classifier: 0.1741 (0.1914)  loss_box_reg: 0.2552 (0.2647)  loss_objectness: 0.0087 (0.0160)  loss_rpn_box_reg: 0.0305 (0.0484)  time: 0.5925  data: 0.0062  max mem: 3288
# Epoch: [1]  [ 30/189]  eta: 0:01:35  lr: 0.005000  loss: 0.5619 (0.5297)  loss_classifier: 0.1876 (0.1900)  loss_box_reg: 0.2552 (0.2631)  loss_objectness: 0.0114 (0.0205)  loss_rpn_box_reg: 0.0326 (0.0561)  time: 0.6001  data: 0.0069  max mem: 3288
# Epoch: [1]  [ 35/189]  eta: 0:01:33  lr: 0.005000  loss: 0.4447 (0.5097)  loss_classifier: 0.1795 (0.1826)  loss_box_reg: 0.2398 (0.2535)  loss_objectness: 0.0065 (0.0187)  loss_rpn_box_reg: 0.0382 (0.0549)  time: 0.6175  data: 0.0070  max mem: 3288
# Epoch: [1]  [ 40/189]  eta: 0:01:30  lr: 0.005000  loss: 0.4447 (0.5153)  loss_classifier: 0.1703 (0.1830)  loss_box_reg: 0.2398 (0.2559)  loss_objectness: 0.0075 (0.0173)  loss_rpn_box_reg: 0.0382 (0.0591)  time: 0.6142  data: 0.0071  max mem: 3288
# Epoch: [1]  [ 45/189]  eta: 0:01:28  lr: 0.005000  loss: 0.5566 (0.5226)  loss_classifier: 0.1737 (0.1808)  loss_box_reg: 0.2619 (0.2584)  loss_objectness: 0.0095 (0.0171)  loss_rpn_box_reg: 0.0399 (0.0663)  time: 0.6363  data: 0.0073  max mem: 3288
# Epoch: [1]  [ 50/189]  eta: 0:01:25  lr: 0.005000  loss: 0.5566 (0.5295)  loss_classifier: 0.1813 (0.1828)  loss_box_reg: 0.2735 (0.2599)  loss_objectness: 0.0095 (0.0211)  loss_rpn_box_reg: 0.0395 (0.0656)  time: 0.6442  data: 0.0073  max mem: 3288
# Epoch: [1]  [ 55/189]  eta: 0:01:22  lr: 0.005000  loss: 0.4952 (0.5219)  loss_classifier: 0.1550 (0.1782)  loss_box_reg: 0.2667 (0.2600)  loss_objectness: 0.0137 (0.0214)  loss_rpn_box_reg: 0.0207 (0.0623)  time: 0.6319  data: 0.0074  max mem: 3288
# Epoch: [1]  [ 60/189]  eta: 0:01:19  lr: 0.005000  loss: 0.4621 (0.5233)  loss_classifier: 0.1349 (0.1793)  loss_box_reg: 0.2625 (0.2601)  loss_objectness: 0.0225 (0.0219)  loss_rpn_box_reg: 0.0207 (0.0621)  time: 0.6222  data: 0.0075  max mem: 3288
# Epoch: [1]  [ 65/189]  eta: 0:01:16  lr: 0.005000  loss: 0.4259 (0.5070)  loss_classifier: 0.1264 (0.1722)  loss_box_reg: 0.2359 (0.2520)  loss_objectness: 0.0222 (0.0211)  loss_rpn_box_reg: 0.0207 (0.0617)  time: 0.6068  data: 0.0074  max mem: 3288
# Epoch: [1]  [ 70/189]  eta: 0:01:12  lr: 0.005000  loss: 0.3876 (0.5010)  loss_classifier: 0.1245 (0.1705)  loss_box_reg: 0.2058 (0.2509)  loss_objectness: 0.0175 (0.0206)  loss_rpn_box_reg: 0.0183 (0.0590)  time: 0.5967  data: 0.0072  max mem: 3288
# Epoch: [1]  [ 75/189]  eta: 0:01:09  lr: 0.005000  loss: 0.4096 (0.5200)  loss_classifier: 0.1362 (0.1713)  loss_box_reg: 0.1925 (0.2495)  loss_objectness: 0.0148 (0.0295)  loss_rpn_box_reg: 0.0235 (0.0696)  time: 0.5997  data: 0.0071  max mem: 3288
# Epoch: [1]  [ 80/189]  eta: 0:01:06  lr: 0.005000  loss: 0.4167 (0.5137)  loss_classifier: 0.1246 (0.1691)  loss_box_reg: 0.1977 (0.2458)  loss_objectness: 0.0148 (0.0297)  loss_rpn_box_reg: 0.0280 (0.0691)  time: 0.5963  data: 0.0074  max mem: 3288
# Epoch: [1]  [ 85/189]  eta: 0:01:03  lr: 0.005000  loss: 0.4461 (0.5182)  loss_classifier: 0.1649 (0.1701)  loss_box_reg: 0.2223 (0.2460)  loss_objectness: 0.0252 (0.0328)  loss_rpn_box_reg: 0.0334 (0.0692)  time: 0.5892  data: 0.0076  max mem: 3288
# Epoch: [1]  [ 90/189]  eta: 0:00:59  lr: 0.005000  loss: 0.4727 (0.5182)  loss_classifier: 0.1649 (0.1697)  loss_box_reg: 0.2264 (0.2441)  loss_objectness: 0.0293 (0.0328)  loss_rpn_box_reg: 0.0373 (0.0716)  time: 0.5808  data: 0.0077  max mem: 3288
# Epoch: [1]  [ 95/189]  eta: 0:00:56  lr: 0.005000  loss: 0.4341 (0.5137)  loss_classifier: 0.1456 (0.1673)  loss_box_reg: 0.2256 (0.2401)  loss_objectness: 0.0282 (0.0346)  loss_rpn_box_reg: 0.0310 (0.0717)  time: 0.5776  data: 0.0079  max mem: 3288
# Epoch: [1]  [100/189]  eta: 0:00:53  lr: 0.005000  loss: 0.4316 (0.5091)  loss_classifier: 0.1437 (0.1661)  loss_box_reg: 0.2062 (0.2377)  loss_objectness: 0.0293 (0.0354)  loss_rpn_box_reg: 0.0310 (0.0700)  time: 0.5736  data: 0.0076  max mem: 3288
# Epoch: [1]  [105/189]  eta: 0:00:50  lr: 0.005000  loss: 0.3920 (0.5085)  loss_classifier: 0.1216 (0.1661)  loss_box_reg: 0.1918 (0.2387)  loss_objectness: 0.0274 (0.0353)  loss_rpn_box_reg: 0.0251 (0.0684)  time: 0.5701  data: 0.0074  max mem: 3288
# Epoch: [1]  [110/189]  eta: 0:00:47  lr: 0.005000  loss: 0.3919 (0.4989)  loss_classifier: 0.1204 (0.1636)  loss_box_reg: 0.1853 (0.2349)  loss_objectness: 0.0234 (0.0343)  loss_rpn_box_reg: 0.0219 (0.0662)  time: 0.5777  data: 0.0073  max mem: 3288
# Epoch: [1]  [115/189]  eta: 0:00:44  lr: 0.005000  loss: 0.3919 (0.4959)  loss_classifier: 0.1331 (0.1627)  loss_box_reg: 0.1918 (0.2339)  loss_objectness: 0.0243 (0.0336)  loss_rpn_box_reg: 0.0238 (0.0656)  time: 0.5640  data: 0.0070  max mem: 3288
# Epoch: [1]  [120/189]  eta: 0:00:41  lr: 0.005000  loss: 0.3919 (0.5098)  loss_classifier: 0.1374 (0.1633)  loss_box_reg: 0.1853 (0.2327)  loss_objectness: 0.0234 (0.0433)  loss_rpn_box_reg: 0.0240 (0.0704)  time: 0.5734  data: 0.0070  max mem: 3288
# Epoch: [1]  [125/189]  eta: 0:00:38  lr: 0.005000  loss: 0.3882 (0.5045)  loss_classifier: 0.1331 (0.1611)  loss_box_reg: 0.1445 (0.2290)  loss_objectness: 0.0263 (0.0444)  loss_rpn_box_reg: 0.0333 (0.0700)  time: 0.5852  data: 0.0072  max mem: 3288
# Epoch: [1]  [130/189]  eta: 0:00:35  lr: 0.005000  loss: 0.3882 (0.4993)  loss_classifier: 0.1331 (0.1597)  loss_box_reg: 0.1621 (0.2271)  loss_objectness: 0.0304 (0.0440)  loss_rpn_box_reg: 0.0341 (0.0685)  time: 0.5852  data: 0.0076  max mem: 3288
# Epoch: [1]  [135/189]  eta: 0:00:32  lr: 0.005000  loss: 0.3882 (0.4963)  loss_classifier: 0.1225 (0.1598)  loss_box_reg: 0.1621 (0.2258)  loss_objectness: 0.0395 (0.0434)  loss_rpn_box_reg: 0.0341 (0.0672)  time: 0.5934  data: 0.0079  max mem: 3288
# Epoch: [1]  [140/189]  eta: 0:00:29  lr: 0.005000  loss: 0.2781 (0.4873)  loss_classifier: 0.0916 (0.1570)  loss_box_reg: 0.1516 (0.2225)  loss_objectness: 0.0248 (0.0424)  loss_rpn_box_reg: 0.0227 (0.0653)  time: 0.6025  data: 0.0080  max mem: 3288
# Epoch: [1]  [145/189]  eta: 0:00:26  lr: 0.005000  loss: 0.3029 (0.4859)  loss_classifier: 0.1095 (0.1573)  loss_box_reg: 0.1767 (0.2224)  loss_objectness: 0.0159 (0.0424)  loss_rpn_box_reg: 0.0177 (0.0638)  time: 0.6008  data: 0.0078  max mem: 3288
# Epoch: [1]  [150/189]  eta: 0:00:23  lr: 0.005000  loss: 0.3789 (0.4912)  loss_classifier: 0.1366 (0.1593)  loss_box_reg: 0.1892 (0.2241)  loss_objectness: 0.0141 (0.0424)  loss_rpn_box_reg: 0.0183 (0.0654)  time: 0.5978  data: 0.0076  max mem: 3288
# Epoch: [1]  [155/189]  eta: 0:00:20  lr: 0.005000  loss: 0.3614 (0.4873)  loss_classifier: 0.1288 (0.1581)  loss_box_reg: 0.1941 (0.2236)  loss_objectness: 0.0141 (0.0415)  loss_rpn_box_reg: 0.0183 (0.0641)  time: 0.5972  data: 0.0073  max mem: 3288
# Epoch: [1]  [160/189]  eta: 0:00:17  lr: 0.005000  loss: 0.4651 (0.4949)  loss_classifier: 0.1604 (0.1591)  loss_box_reg: 0.2017 (0.2231)  loss_objectness: 0.0188 (0.0468)  loss_rpn_box_reg: 0.0205 (0.0658)  time: 0.5907  data: 0.0078  max mem: 3288
# Epoch: [1]  [165/189]  eta: 0:00:14  lr: 0.005000  loss: 0.4651 (0.4937)  loss_classifier: 0.1442 (0.1586)  loss_box_reg: 0.1967 (0.2230)  loss_objectness: 0.0341 (0.0471)  loss_rpn_box_reg: 0.0227 (0.0649)  time: 0.5838  data: 0.0083  max mem: 3288
# Epoch: [1]  [170/189]  eta: 0:00:11  lr: 0.005000  loss: 0.4651 (0.4951)  loss_classifier: 0.1409 (0.1582)  loss_box_reg: 0.1967 (0.2234)  loss_objectness: 0.0353 (0.0478)  loss_rpn_box_reg: 0.0244 (0.0657)  time: 0.5819  data: 0.0085  max mem: 3288
# Epoch: [1]  [175/189]  eta: 0:00:08  lr: 0.005000  loss: 0.4536 (0.4918)  loss_classifier: 0.1400 (0.1574)  loss_box_reg: 0.1967 (0.2224)  loss_objectness: 0.0601 (0.0474)  loss_rpn_box_reg: 0.0328 (0.0647)  time: 0.5845  data: 0.0086  max mem: 3288
# Epoch: [1]  [180/189]  eta: 0:00:05  lr: 0.005000  loss: 0.4229 (0.4904)  loss_classifier: 0.1171 (0.1564)  loss_box_reg: 0.1829 (0.2224)  loss_objectness: 0.0440 (0.0472)  loss_rpn_box_reg: 0.0328 (0.0644)  time: 0.5798  data: 0.0080  max mem: 3288
# Epoch: [1]  [185/189]  eta: 0:00:02  lr: 0.005000  loss: 0.4234 (0.4954)  loss_classifier: 0.1228 (0.1578)  loss_box_reg: 0.2105 (0.2248)  loss_objectness: 0.0380 (0.0486)  loss_rpn_box_reg: 0.0343 (0.0642)  time: 0.5894  data: 0.0075  max mem: 3288
# Epoch: [1]  [188/189]  eta: 0:00:00  lr: 0.005000  loss: 0.3998 (0.4939)  loss_classifier: 0.1228 (0.1575)  loss_box_reg: 0.1996 (0.2244)  loss_objectness: 0.0288 (0.0483)  loss_rpn_box_reg: 0.0310 (0.0638)  time: 0.5891  data: 0.0072  max mem: 3288
# Epoch: [1] Total time: 0:01:52 (0.5961 s / it)
# creating index...
# index created!
# Test:  [ 0/25]  eta: 0:00:14  model_time: 0.3009 (0.3009)  evaluator_time: 0.0081 (0.0081)  time: 0.5807  data: 0.2678  max mem: 3288
# Test:  [24/25]  eta: 0:00:00  model_time: 0.2410 (0.2509)  evaluator_time: 0.0119 (0.0151)  time: 0.2722  data: 0.0056  max mem: 3288
# Test: Total time: 0:00:07 (0.2893 s / it)
# Averaged stats: model_time: 0.2410 (0.2509)  evaluator_time: 0.0119 (0.0151)
# Accumulating evaluation results...
# DONE (t=0.05s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.337
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.689
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.276
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.125
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.387
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.251
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.112
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.466
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.534
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.270
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.563
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.468
# Epoch: [2]  [  0/189]  eta: 0:02:45  lr: 0.005000  loss: 0.5742 (0.5742)  loss_classifier: 0.2174 (0.2174)  loss_box_reg: 0.2366 (0.2366)  loss_objectness: 0.0511 (0.0511)  loss_rpn_box_reg: 0.0691 (0.0691)  time: 0.8734  data: 0.2216  max mem: 3288
# Epoch: [2]  [  5/189]  eta: 0:01:58  lr: 0.005000  loss: 0.3289 (0.3703)  loss_classifier: 0.0897 (0.1188)  loss_box_reg: 0.1712 (0.1819)  loss_objectness: 0.0274 (0.0330)  loss_rpn_box_reg: 0.0144 (0.0366)  time: 0.6463  data: 0.0457  max mem: 3288
# Epoch: [2]  [ 10/189]  eta: 0:01:53  lr: 0.005000  loss: 0.3289 (0.4958)  loss_classifier: 0.1083 (0.1255)  loss_box_reg: 0.1712 (0.1917)  loss_objectness: 0.0274 (0.0611)  loss_rpn_box_reg: 0.0144 (0.1175)  time: 0.6317  data: 0.0272  max mem: 3288
# Epoch: [2]  [ 15/189]  eta: 0:01:46  lr: 0.005000  loss: 0.3385 (0.4599)  loss_classifier: 0.1114 (0.1266)  loss_box_reg: 0.1713 (0.1902)  loss_objectness: 0.0178 (0.0480)  loss_rpn_box_reg: 0.0188 (0.0952)  time: 0.6119  data: 0.0209  max mem: 3288
# Epoch: [2]  [ 20/189]  eta: 0:01:43  lr: 0.005000  loss: 0.3385 (0.4424)  loss_classifier: 0.1114 (0.1270)  loss_box_reg: 0.1740 (0.1965)  loss_objectness: 0.0178 (0.0410)  loss_rpn_box_reg: 0.0188 (0.0779)  time: 0.6006  data: 0.0075  max mem: 3288
# Epoch: [2]  [ 25/189]  eta: 0:01:40  lr: 0.005000  loss: 0.3445 (0.4382)  loss_classifier: 0.1276 (0.1256)  loss_box_reg: 0.1774 (0.1927)  loss_objectness: 0.0125 (0.0408)  loss_rpn_box_reg: 0.0218 (0.0791)  time: 0.6011  data: 0.0065  max mem: 3288
# Epoch: [2]  [ 30/189]  eta: 0:01:37  lr: 0.005000  loss: 0.4113 (0.4552)  loss_classifier: 0.1280 (0.1290)  loss_box_reg: 0.1840 (0.2057)  loss_objectness: 0.0187 (0.0390)  loss_rpn_box_reg: 0.0298 (0.0815)  time: 0.5997  data: 0.0072  max mem: 3288
# Epoch: [2]  [ 35/189]  eta: 0:01:33  lr: 0.005000  loss: 0.4113 (0.4481)  loss_classifier: 0.1276 (0.1270)  loss_box_reg: 0.2396 (0.2081)  loss_objectness: 0.0191 (0.0382)  loss_rpn_box_reg: 0.0298 (0.0748)  time: 0.5999  data: 0.0074  max mem: 3288
# Epoch: [2]  [ 40/189]  eta: 0:01:29  lr: 0.005000  loss: 0.4065 (0.4385)  loss_classifier: 0.1199 (0.1249)  loss_box_reg: 0.2185 (0.2083)  loss_objectness: 0.0196 (0.0365)  loss_rpn_box_reg: 0.0343 (0.0688)  time: 0.5869  data: 0.0073  max mem: 3288
# Epoch: [2]  [ 45/189]  eta: 0:01:26  lr: 0.005000  loss: 0.4065 (0.4378)  loss_classifier: 0.1150 (0.1277)  loss_box_reg: 0.2489 (0.2104)  loss_objectness: 0.0266 (0.0349)  loss_rpn_box_reg: 0.0379 (0.0648)  time: 0.5913  data: 0.0074  max mem: 3288
# Epoch: [2]  [ 50/189]  eta: 0:01:23  lr: 0.005000  loss: 0.3334 (0.4215)  loss_classifier: 0.1028 (0.1241)  loss_box_reg: 0.1614 (0.2039)  loss_objectness: 0.0171 (0.0326)  loss_rpn_box_reg: 0.0175 (0.0610)  time: 0.5801  data: 0.0074  max mem: 3288
# Epoch: [2]  [ 55/189]  eta: 0:01:20  lr: 0.005000  loss: 0.2863 (0.4094)  loss_classifier: 0.0940 (0.1203)  loss_box_reg: 0.1430 (0.2009)  loss_objectness: 0.0120 (0.0305)  loss_rpn_box_reg: 0.0173 (0.0576)  time: 0.5870  data: 0.0074  max mem: 3288
# Epoch: [2]  [ 60/189]  eta: 0:01:16  lr: 0.005000  loss: 0.2863 (0.4095)  loss_classifier: 0.0940 (0.1248)  loss_box_reg: 0.1511 (0.2006)  loss_objectness: 0.0086 (0.0291)  loss_rpn_box_reg: 0.0152 (0.0551)  time: 0.5874  data: 0.0076  max mem: 3288
# Epoch: [2]  [ 65/189]  eta: 0:01:14  lr: 0.005000  loss: 0.3226 (0.4260)  loss_classifier: 0.0984 (0.1267)  loss_box_reg: 0.1640 (0.2030)  loss_objectness: 0.0083 (0.0333)  loss_rpn_box_reg: 0.0203 (0.0630)  time: 0.5855  data: 0.0074  max mem: 3288
# Epoch: [2]  [ 70/189]  eta: 0:01:11  lr: 0.005000  loss: 0.3870 (0.4251)  loss_classifier: 0.1270 (0.1277)  loss_box_reg: 0.1803 (0.2044)  loss_objectness: 0.0110 (0.0320)  loss_rpn_box_reg: 0.0242 (0.0609)  time: 0.5930  data: 0.0073  max mem: 3288
# Epoch: [2]  [ 75/189]  eta: 0:01:08  lr: 0.005000  loss: 0.3861 (0.4141)  loss_classifier: 0.1173 (0.1242)  loss_box_reg: 0.1800 (0.2010)  loss_objectness: 0.0111 (0.0308)  loss_rpn_box_reg: 0.0213 (0.0581)  time: 0.5975  data: 0.0075  max mem: 3590
# Epoch: [2]  [ 80/189]  eta: 0:01:05  lr: 0.005000  loss: 0.3870 (0.4195)  loss_classifier: 0.1201 (0.1261)  loss_box_reg: 0.2030 (0.2030)  loss_objectness: 0.0129 (0.0304)  loss_rpn_box_reg: 0.0310 (0.0599)  time: 0.5967  data: 0.0074  max mem: 3590
# Epoch: [2]  [ 85/189]  eta: 0:01:01  lr: 0.005000  loss: 0.3764 (0.4209)  loss_classifier: 0.1201 (0.1278)  loss_box_reg: 0.2030 (0.2051)  loss_objectness: 0.0148 (0.0298)  loss_rpn_box_reg: 0.0304 (0.0582)  time: 0.5906  data: 0.0074  max mem: 3590
# Epoch: [2]  [ 90/189]  eta: 0:00:59  lr: 0.005000  loss: 0.3755 (0.4255)  loss_classifier: 0.0931 (0.1273)  loss_box_reg: 0.1861 (0.2049)  loss_objectness: 0.0151 (0.0298)  loss_rpn_box_reg: 0.0310 (0.0636)  time: 0.5925  data: 0.0079  max mem: 3590
# Epoch: [2]  [ 95/189]  eta: 0:00:55  lr: 0.005000  loss: 0.4298 (0.4195)  loss_classifier: 0.1125 (0.1250)  loss_box_reg: 0.2034 (0.2049)  loss_objectness: 0.0132 (0.0286)  loss_rpn_box_reg: 0.0304 (0.0610)  time: 0.5806  data: 0.0075  max mem: 3590
# Epoch: [2]  [100/189]  eta: 0:00:52  lr: 0.005000  loss: 0.3755 (0.4198)  loss_classifier: 0.1125 (0.1256)  loss_box_reg: 0.2034 (0.2055)  loss_objectness: 0.0123 (0.0278)  loss_rpn_box_reg: 0.0198 (0.0609)  time: 0.5887  data: 0.0074  max mem: 3590
# Epoch: [2]  [105/189]  eta: 0:00:49  lr: 0.005000  loss: 0.3755 (0.4190)  loss_classifier: 0.1152 (0.1255)  loss_box_reg: 0.1844 (0.2066)  loss_objectness: 0.0104 (0.0271)  loss_rpn_box_reg: 0.0198 (0.0598)  time: 0.5880  data: 0.0075  max mem: 3590
# Epoch: [2]  [110/189]  eta: 0:00:46  lr: 0.005000  loss: 0.3983 (0.4247)  loss_classifier: 0.1187 (0.1263)  loss_box_reg: 0.1923 (0.2107)  loss_objectness: 0.0104 (0.0268)  loss_rpn_box_reg: 0.0198 (0.0609)  time: 0.5876  data: 0.0072  max mem: 3590
# Epoch: [2]  [115/189]  eta: 0:00:43  lr: 0.005000  loss: 0.3707 (0.4217)  loss_classifier: 0.1241 (0.1248)  loss_box_reg: 0.1958 (0.2107)  loss_objectness: 0.0108 (0.0263)  loss_rpn_box_reg: 0.0268 (0.0598)  time: 0.5924  data: 0.0071  max mem: 3590
# Epoch: [2]  [120/189]  eta: 0:00:41  lr: 0.005000  loss: 0.3550 (0.4172)  loss_classifier: 0.1047 (0.1231)  loss_box_reg: 0.1923 (0.2078)  loss_objectness: 0.0141 (0.0258)  loss_rpn_box_reg: 0.0268 (0.0604)  time: 0.6013  data: 0.0074  max mem: 3590
# Epoch: [2]  [125/189]  eta: 0:00:38  lr: 0.005000  loss: 0.3337 (0.4122)  loss_classifier: 0.0897 (0.1214)  loss_box_reg: 0.1700 (0.2056)  loss_objectness: 0.0141 (0.0252)  loss_rpn_box_reg: 0.0268 (0.0599)  time: 0.5977  data: 0.0073  max mem: 3590
# Epoch: [2]  [130/189]  eta: 0:00:35  lr: 0.005000  loss: 0.3013 (0.4071)  loss_classifier: 0.0793 (0.1200)  loss_box_reg: 0.1626 (0.2039)  loss_objectness: 0.0088 (0.0246)  loss_rpn_box_reg: 0.0253 (0.0586)  time: 0.5889  data: 0.0078  max mem: 3590
# Epoch: [2]  [135/189]  eta: 0:00:32  lr: 0.005000  loss: 0.2760 (0.4040)  loss_classifier: 0.0793 (0.1190)  loss_box_reg: 0.1600 (0.2032)  loss_objectness: 0.0073 (0.0240)  loss_rpn_box_reg: 0.0253 (0.0577)  time: 0.5842  data: 0.0078  max mem: 3590
# Epoch: [2]  [140/189]  eta: 0:00:29  lr: 0.005000  loss: 0.2889 (0.4011)  loss_classifier: 0.0793 (0.1179)  loss_box_reg: 0.1496 (0.2012)  loss_objectness: 0.0079 (0.0240)  loss_rpn_box_reg: 0.0307 (0.0581)  time: 0.5752  data: 0.0074  max mem: 3590
# Epoch: [2]  [145/189]  eta: 0:00:26  lr: 0.005000  loss: 0.3187 (0.4021)  loss_classifier: 0.1019 (0.1182)  loss_box_reg: 0.1693 (0.2012)  loss_objectness: 0.0079 (0.0237)  loss_rpn_box_reg: 0.0374 (0.0589)  time: 0.5779  data: 0.0074  max mem: 3590
# Epoch: [2]  [150/189]  eta: 0:00:23  lr: 0.005000  loss: 0.3373 (0.4011)  loss_classifier: 0.1084 (0.1180)  loss_box_reg: 0.1693 (0.2008)  loss_objectness: 0.0131 (0.0236)  loss_rpn_box_reg: 0.0393 (0.0588)  time: 0.5781  data: 0.0069  max mem: 3590
# Epoch: [2]  [155/189]  eta: 0:00:20  lr: 0.005000  loss: 0.3515 (0.4011)  loss_classifier: 0.1093 (0.1178)  loss_box_reg: 0.1496 (0.1996)  loss_objectness: 0.0174 (0.0237)  loss_rpn_box_reg: 0.0422 (0.0600)  time: 0.5894  data: 0.0071  max mem: 3590
# Epoch: [2]  [160/189]  eta: 0:00:17  lr: 0.005000  loss: 0.3462 (0.3979)  loss_classifier: 0.1095 (0.1170)  loss_box_reg: 0.1870 (0.1987)  loss_objectness: 0.0162 (0.0234)  loss_rpn_box_reg: 0.0374 (0.0588)  time: 0.5858  data: 0.0072  max mem: 3590
# Epoch: [2]  [165/189]  eta: 0:00:14  lr: 0.005000  loss: 0.3462 (0.3962)  loss_classifier: 0.1002 (0.1168)  loss_box_reg: 0.1870 (0.1989)  loss_objectness: 0.0137 (0.0230)  loss_rpn_box_reg: 0.0265 (0.0576)  time: 0.5877  data: 0.0075  max mem: 3590
# Epoch: [2]  [170/189]  eta: 0:00:11  lr: 0.005000  loss: 0.3462 (0.3950)  loss_classifier: 0.0956 (0.1164)  loss_box_reg: 0.1952 (0.1997)  loss_objectness: 0.0092 (0.0225)  loss_rpn_box_reg: 0.0195 (0.0564)  time: 0.5927  data: 0.0076  max mem: 3590
# Epoch: [2]  [175/189]  eta: 0:00:08  lr: 0.005000  loss: 0.3843 (0.3967)  loss_classifier: 0.1000 (0.1171)  loss_box_reg: 0.2259 (0.2015)  loss_objectness: 0.0086 (0.0222)  loss_rpn_box_reg: 0.0195 (0.0559)  time: 0.5873  data: 0.0079  max mem: 3590
# Epoch: [2]  [180/189]  eta: 0:00:05  lr: 0.005000  loss: 0.4082 (0.4005)  loss_classifier: 0.1215 (0.1192)  loss_box_reg: 0.2304 (0.2032)  loss_objectness: 0.0086 (0.0226)  loss_rpn_box_reg: 0.0195 (0.0556)  time: 0.5892  data: 0.0085  max mem: 3590
# Epoch: [2]  [185/189]  eta: 0:00:02  lr: 0.005000  loss: 0.4082 (0.4018)  loss_classifier: 0.1316 (0.1202)  loss_box_reg: 0.2334 (0.2046)  loss_objectness: 0.0103 (0.0223)  loss_rpn_box_reg: 0.0214 (0.0547)  time: 0.5973  data: 0.0081  max mem: 3590
# Epoch: [2]  [188/189]  eta: 0:00:00  lr: 0.005000  loss: 0.4295 (0.4018)  loss_classifier: 0.1316 (0.1206)  loss_box_reg: 0.2455 (0.2050)  loss_objectness: 0.0103 (0.0221)  loss_rpn_box_reg: 0.0203 (0.0542)  time: 0.5972  data: 0.0080  max mem: 3590
# Epoch: [2] Total time: 0:01:52 (0.5932 s / it)
# creating index...
# index created!
# Test:  [ 0/25]  eta: 0:00:14  model_time: 0.3039 (0.3039)  evaluator_time: 0.0054 (0.0054)  time: 0.5893  data: 0.2727  max mem: 3590
# Test:  [24/25]  eta: 0:00:00  model_time: 0.2397 (0.2507)  evaluator_time: 0.0076 (0.0094)  time: 0.2672  data: 0.0063  max mem: 3590
# Test: Total time: 0:00:07 (0.2842 s / it)
# Averaged stats: model_time: 0.2397 (0.2507)  evaluator_time: 0.0076 (0.0094)
# Accumulating evaluation results...
# DONE (t=0.04s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.374
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.729
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.357
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.193
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.428
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.326
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.127
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.513
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.550
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.311
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.566
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.531
# Epoch: [3]  [  0/189]  eta: 0:03:00  lr: 0.000500  loss: 0.2669 (0.2669)  loss_classifier: 0.0915 (0.0915)  loss_box_reg: 0.1570 (0.1570)  loss_objectness: 0.0084 (0.0084)  loss_rpn_box_reg: 0.0101 (0.0101)  time: 0.9552  data: 0.3799  max mem: 3590
# Epoch: [3]  [  5/189]  eta: 0:01:57  lr: 0.000500  loss: 0.2669 (0.2912)  loss_classifier: 0.0837 (0.0883)  loss_box_reg: 0.1605 (0.1657)  loss_objectness: 0.0074 (0.0098)  loss_rpn_box_reg: 0.0131 (0.0273)  time: 0.6375  data: 0.0672  max mem: 3590
# Epoch: [3]  [ 10/189]  eta: 0:01:49  lr: 0.000500  loss: 0.2843 (0.3577)  loss_classifier: 0.1027 (0.1026)  loss_box_reg: 0.1689 (0.1899)  loss_objectness: 0.0108 (0.0119)  loss_rpn_box_reg: 0.0266 (0.0533)  time: 0.6127  data: 0.0402  max mem: 3590
# Epoch: [3]  [ 15/189]  eta: 0:01:44  lr: 0.000500  loss: 0.3211 (0.3690)  loss_classifier: 0.1027 (0.1069)  loss_box_reg: 0.1880 (0.2049)  loss_objectness: 0.0108 (0.0130)  loss_rpn_box_reg: 0.0160 (0.0442)  time: 0.6014  data: 0.0301  max mem: 3590
# Epoch: [3]  [ 20/189]  eta: 0:01:41  lr: 0.000500  loss: 0.3023 (0.3397)  loss_classifier: 0.0955 (0.0987)  loss_box_reg: 0.1822 (0.1926)  loss_objectness: 0.0101 (0.0112)  loss_rpn_box_reg: 0.0157 (0.0371)  time: 0.5830  data: 0.0068  max mem: 3590
# Epoch: [3]  [ 25/189]  eta: 0:01:39  lr: 0.000500  loss: 0.3390 (0.3554)  loss_classifier: 0.1057 (0.1029)  loss_box_reg: 0.1901 (0.2030)  loss_objectness: 0.0101 (0.0128)  loss_rpn_box_reg: 0.0153 (0.0367)  time: 0.5968  data: 0.0076  max mem: 3590
# Epoch: [3]  [ 30/189]  eta: 0:01:35  lr: 0.000500  loss: 0.2798 (0.3283)  loss_classifier: 0.0787 (0.0950)  loss_box_reg: 0.1700 (0.1891)  loss_objectness: 0.0079 (0.0117)  loss_rpn_box_reg: 0.0124 (0.0324)  time: 0.5956  data: 0.0078  max mem: 3590
# Epoch: [3]  [ 35/189]  eta: 0:01:32  lr: 0.000500  loss: 0.2278 (0.3203)  loss_classifier: 0.0680 (0.0951)  loss_box_reg: 0.1277 (0.1803)  loss_objectness: 0.0073 (0.0120)  loss_rpn_box_reg: 0.0137 (0.0328)  time: 0.6009  data: 0.0079  max mem: 3590
# Epoch: [3]  [ 40/189]  eta: 0:01:29  lr: 0.000500  loss: 0.2414 (0.3277)  loss_classifier: 0.0680 (0.0958)  loss_box_reg: 0.1277 (0.1755)  loss_objectness: 0.0073 (0.0131)  loss_rpn_box_reg: 0.0144 (0.0433)  time: 0.6003  data: 0.0081  max mem: 3590
# Epoch: [3]  [ 45/189]  eta: 0:01:26  lr: 0.000500  loss: 0.2608 (0.3378)  loss_classifier: 0.0680 (0.1000)  loss_box_reg: 0.1277 (0.1826)  loss_objectness: 0.0070 (0.0126)  loss_rpn_box_reg: 0.0148 (0.0426)  time: 0.5982  data: 0.0083  max mem: 3590
# Epoch: [3]  [ 50/189]  eta: 0:01:23  lr: 0.000500  loss: 0.3520 (0.3456)  loss_classifier: 0.0849 (0.1013)  loss_box_reg: 0.1827 (0.1884)  loss_objectness: 0.0077 (0.0121)  loss_rpn_box_reg: 0.0227 (0.0438)  time: 0.6053  data: 0.0078  max mem: 3590
# Epoch: [3]  [ 55/189]  eta: 0:01:20  lr: 0.000500  loss: 0.3520 (0.3405)  loss_classifier: 0.0959 (0.1010)  loss_box_reg: 0.1942 (0.1854)  loss_objectness: 0.0077 (0.0117)  loss_rpn_box_reg: 0.0203 (0.0423)  time: 0.5982  data: 0.0076  max mem: 3590
# Epoch: [3]  [ 60/189]  eta: 0:01:17  lr: 0.000500  loss: 0.3376 (0.3400)  loss_classifier: 0.0950 (0.1014)  loss_box_reg: 0.1986 (0.1849)  loss_objectness: 0.0077 (0.0116)  loss_rpn_box_reg: 0.0203 (0.0421)  time: 0.5912  data: 0.0074  max mem: 3590
# Epoch: [3]  [ 65/189]  eta: 0:01:13  lr: 0.000500  loss: 0.2837 (0.3371)  loss_classifier: 0.0868 (0.1013)  loss_box_reg: 0.1698 (0.1834)  loss_objectness: 0.0077 (0.0118)  loss_rpn_box_reg: 0.0203 (0.0406)  time: 0.5828  data: 0.0072  max mem: 3590
# Epoch: [3]  [ 70/189]  eta: 0:01:10  lr: 0.000500  loss: 0.2572 (0.3372)  loss_classifier: 0.0848 (0.1015)  loss_box_reg: 0.1319 (0.1850)  loss_objectness: 0.0073 (0.0114)  loss_rpn_box_reg: 0.0156 (0.0392)  time: 0.5787  data: 0.0073  max mem: 3590
# Epoch: [3]  [ 75/189]  eta: 0:01:07  lr: 0.000500  loss: 0.2558 (0.3329)  loss_classifier: 0.0848 (0.1019)  loss_box_reg: 0.1285 (0.1801)  loss_objectness: 0.0066 (0.0112)  loss_rpn_box_reg: 0.0151 (0.0397)  time: 0.5857  data: 0.0076  max mem: 3590
# Epoch: [3]  [ 80/189]  eta: 0:01:04  lr: 0.000500  loss: 0.2758 (0.3301)  loss_classifier: 0.0881 (0.1012)  loss_box_reg: 0.1285 (0.1792)  loss_objectness: 0.0061 (0.0109)  loss_rpn_box_reg: 0.0151 (0.0389)  time: 0.5878  data: 0.0077  max mem: 3590
# Epoch: [3]  [ 85/189]  eta: 0:01:01  lr: 0.000500  loss: 0.2494 (0.3275)  loss_classifier: 0.0848 (0.1011)  loss_box_reg: 0.1249 (0.1780)  loss_objectness: 0.0060 (0.0106)  loss_rpn_box_reg: 0.0131 (0.0378)  time: 0.5846  data: 0.0079  max mem: 3590
# Epoch: [3]  [ 90/189]  eta: 0:00:58  lr: 0.000500  loss: 0.2406 (0.3249)  loss_classifier: 0.0841 (0.1006)  loss_box_reg: 0.1246 (0.1766)  loss_objectness: 0.0060 (0.0104)  loss_rpn_box_reg: 0.0135 (0.0374)  time: 0.5790  data: 0.0079  max mem: 3590
# Epoch: [3]  [ 95/189]  eta: 0:00:55  lr: 0.000500  loss: 0.2769 (0.3302)  loss_classifier: 0.0865 (0.1008)  loss_box_reg: 0.1525 (0.1772)  loss_objectness: 0.0061 (0.0105)  loss_rpn_box_reg: 0.0150 (0.0416)  time: 0.5827  data: 0.0075  max mem: 3590
# Epoch: [3]  [100/189]  eta: 0:00:52  lr: 0.000500  loss: 0.2689 (0.3250)  loss_classifier: 0.0841 (0.0993)  loss_box_reg: 0.1555 (0.1754)  loss_objectness: 0.0056 (0.0102)  loss_rpn_box_reg: 0.0131 (0.0401)  time: 0.5835  data: 0.0076  max mem: 3590
# Epoch: [3]  [105/189]  eta: 0:00:49  lr: 0.000500  loss: 0.2782 (0.3244)  loss_classifier: 0.0843 (0.0995)  loss_box_reg: 0.1525 (0.1753)  loss_objectness: 0.0056 (0.0101)  loss_rpn_box_reg: 0.0147 (0.0394)  time: 0.5809  data: 0.0072  max mem: 3590
# Epoch: [3]  [110/189]  eta: 0:00:46  lr: 0.000500  loss: 0.2782 (0.3317)  loss_classifier: 0.0869 (0.0993)  loss_box_reg: 0.1632 (0.1748)  loss_objectness: 0.0050 (0.0123)  loss_rpn_box_reg: 0.0146 (0.0453)  time: 0.5892  data: 0.0072  max mem: 3590
# Epoch: [3]  [115/189]  eta: 0:00:43  lr: 0.000500  loss: 0.2647 (0.3274)  loss_classifier: 0.0831 (0.0980)  loss_box_reg: 0.1632 (0.1738)  loss_objectness: 0.0044 (0.0119)  loss_rpn_box_reg: 0.0114 (0.0438)  time: 0.5891  data: 0.0074  max mem: 3590
# Epoch: [3]  [120/189]  eta: 0:00:40  lr: 0.000500  loss: 0.2951 (0.3292)  loss_classifier: 0.0958 (0.0992)  loss_box_reg: 0.1796 (0.1754)  loss_objectness: 0.0051 (0.0118)  loss_rpn_box_reg: 0.0126 (0.0428)  time: 0.5906  data: 0.0075  max mem: 3590
# Epoch: [3]  [125/189]  eta: 0:00:37  lr: 0.000500  loss: 0.2983 (0.3291)  loss_classifier: 0.0967 (0.0992)  loss_box_reg: 0.1797 (0.1756)  loss_objectness: 0.0061 (0.0119)  loss_rpn_box_reg: 0.0140 (0.0424)  time: 0.5920  data: 0.0074  max mem: 3590
# Epoch: [3]  [130/189]  eta: 0:00:34  lr: 0.000500  loss: 0.2951 (0.3274)  loss_classifier: 0.0831 (0.0992)  loss_box_reg: 0.1826 (0.1752)  loss_objectness: 0.0079 (0.0118)  loss_rpn_box_reg: 0.0126 (0.0412)  time: 0.5913  data: 0.0074  max mem: 3590
# Epoch: [3]  [135/189]  eta: 0:00:31  lr: 0.000500  loss: 0.3298 (0.3300)  loss_classifier: 0.0969 (0.1000)  loss_box_reg: 0.1875 (0.1769)  loss_objectness: 0.0095 (0.0116)  loss_rpn_box_reg: 0.0175 (0.0414)  time: 0.5798  data: 0.0073  max mem: 3590
# Epoch: [3]  [140/189]  eta: 0:00:28  lr: 0.000500  loss: 0.2774 (0.3309)  loss_classifier: 0.0858 (0.1005)  loss_box_reg: 0.1584 (0.1778)  loss_objectness: 0.0101 (0.0117)  loss_rpn_box_reg: 0.0175 (0.0409)  time: 0.5790  data: 0.0071  max mem: 3590
# Epoch: [3]  [145/189]  eta: 0:00:25  lr: 0.000500  loss: 0.2752 (0.3359)  loss_classifier: 0.0858 (0.1019)  loss_box_reg: 0.1601 (0.1787)  loss_objectness: 0.0095 (0.0122)  loss_rpn_box_reg: 0.0175 (0.0431)  time: 0.5826  data: 0.0074  max mem: 3590
# Epoch: [3]  [150/189]  eta: 0:00:23  lr: 0.000500  loss: 0.2696 (0.3323)  loss_classifier: 0.0858 (0.1011)  loss_box_reg: 0.1584 (0.1768)  loss_objectness: 0.0101 (0.0122)  loss_rpn_box_reg: 0.0189 (0.0422)  time: 0.5833  data: 0.0073  max mem: 3590
# Epoch: [3]  [155/189]  eta: 0:00:20  lr: 0.000500  loss: 0.2696 (0.3305)  loss_classifier: 0.0858 (0.1008)  loss_box_reg: 0.1390 (0.1761)  loss_objectness: 0.0109 (0.0122)  loss_rpn_box_reg: 0.0189 (0.0414)  time: 0.6008  data: 0.0078  max mem: 3590
# Epoch: [3]  [160/189]  eta: 0:00:17  lr: 0.000500  loss: 0.2261 (0.3264)  loss_classifier: 0.0669 (0.0996)  loss_box_reg: 0.1245 (0.1743)  loss_objectness: 0.0079 (0.0119)  loss_rpn_box_reg: 0.0161 (0.0406)  time: 0.5972  data: 0.0077  max mem: 3590
# Epoch: [3]  [165/189]  eta: 0:00:14  lr: 0.000500  loss: 0.2213 (0.3264)  loss_classifier: 0.0669 (0.0995)  loss_box_reg: 0.1353 (0.1750)  loss_objectness: 0.0060 (0.0119)  loss_rpn_box_reg: 0.0161 (0.0401)  time: 0.5947  data: 0.0075  max mem: 3590
# Epoch: [3]  [170/189]  eta: 0:00:11  lr: 0.000500  loss: 0.2337 (0.3277)  loss_classifier: 0.0726 (0.0994)  loss_box_reg: 0.1353 (0.1747)  loss_objectness: 0.0047 (0.0119)  loss_rpn_box_reg: 0.0164 (0.0416)  time: 0.5932  data: 0.0077  max mem: 3590
# Epoch: [3]  [175/189]  eta: 0:00:08  lr: 0.000500  loss: 0.2337 (0.3267)  loss_classifier: 0.0726 (0.0995)  loss_box_reg: 0.1412 (0.1747)  loss_objectness: 0.0044 (0.0117)  loss_rpn_box_reg: 0.0154 (0.0408)  time: 0.5806  data: 0.0071  max mem: 3590
# Epoch: [3]  [180/189]  eta: 0:00:05  lr: 0.000500  loss: 0.2527 (0.3264)  loss_classifier: 0.0889 (0.0996)  loss_box_reg: 0.1472 (0.1745)  loss_objectness: 0.0044 (0.0115)  loss_rpn_box_reg: 0.0249 (0.0408)  time: 0.5861  data: 0.0072  max mem: 3590
# Epoch: [3]  [185/189]  eta: 0:00:02  lr: 0.000500  loss: 0.2799 (0.3283)  loss_classifier: 0.0917 (0.1007)  loss_box_reg: 0.1482 (0.1753)  loss_objectness: 0.0050 (0.0115)  loss_rpn_box_reg: 0.0237 (0.0407)  time: 0.6012  data: 0.0071  max mem: 3590
# Epoch: [3]  [188/189]  eta: 0:00:00  lr: 0.000500  loss: 0.2527 (0.3274)  loss_classifier: 0.0917 (0.1005)  loss_box_reg: 0.1469 (0.1743)  loss_objectness: 0.0047 (0.0115)  loss_rpn_box_reg: 0.0136 (0.0411)  time: 0.6069  data: 0.0070  max mem: 3656
# Epoch: [3] Total time: 0:01:52 (0.5936 s / it)
# creating index...
# index created!
# Test:  [ 0/25]  eta: 0:00:12  model_time: 0.2961 (0.2961)  evaluator_time: 0.0049 (0.0049)  time: 0.5094  data: 0.2003  max mem: 3656
# Test:  [24/25]  eta: 0:00:00  model_time: 0.2391 (0.2503)  evaluator_time: 0.0052 (0.0070)  time: 0.2636  data: 0.0065  max mem: 3656
# Test: Total time: 0:00:06 (0.2782 s / it)
# Averaged stats: model_time: 0.2391 (0.2503)  evaluator_time: 0.0052 (0.0070)
# Accumulating evaluation results...
# DONE (t=0.03s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.467
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.787
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.460
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.290
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.500
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.404
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.154
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.565
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.597
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.306
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.610
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.620
# Epoch: [4]  [  0/189]  eta: 0:03:11  lr: 0.000500  loss: 0.2571 (0.2571)  loss_classifier: 0.0825 (0.0825)  loss_box_reg: 0.1612 (0.1612)  loss_objectness: 0.0032 (0.0032)  loss_rpn_box_reg: 0.0104 (0.0104)  time: 1.0153  data: 0.3967  max mem: 3656
# Epoch: [4]  [  5/189]  eta: 0:02:01  lr: 0.000500  loss: 0.2018 (0.1905)  loss_classifier: 0.0511 (0.0632)  loss_box_reg: 0.1338 (0.1146)  loss_objectness: 0.0032 (0.0033)  loss_rpn_box_reg: 0.0104 (0.0094)  time: 0.6610  data: 0.0735  max mem: 3656
# Epoch: [4]  [ 10/189]  eta: 0:01:53  lr: 0.000500  loss: 0.2018 (0.1990)  loss_classifier: 0.0511 (0.0662)  loss_box_reg: 0.1338 (0.1138)  loss_objectness: 0.0064 (0.0062)  loss_rpn_box_reg: 0.0105 (0.0128)  time: 0.6314  data: 0.0416  max mem: 3656
# Epoch: [4]  [ 15/189]  eta: 0:01:47  lr: 0.000500  loss: 0.2220 (0.2173)  loss_classifier: 0.0674 (0.0686)  loss_box_reg: 0.1338 (0.1236)  loss_objectness: 0.0063 (0.0063)  loss_rpn_box_reg: 0.0108 (0.0188)  time: 0.6174  data: 0.0308  max mem: 3656
# Epoch: [4]  [ 20/189]  eta: 0:01:43  lr: 0.000500  loss: 0.2235 (0.2438)  loss_classifier: 0.0695 (0.0789)  loss_box_reg: 0.1338 (0.1385)  loss_objectness: 0.0065 (0.0082)  loss_rpn_box_reg: 0.0113 (0.0182)  time: 0.5939  data: 0.0066  max mem: 3656
# Epoch: [4]  [ 25/189]  eta: 0:01:39  lr: 0.000500  loss: 0.2586 (0.2638)  loss_classifier: 0.0838 (0.0832)  loss_box_reg: 0.1503 (0.1471)  loss_objectness: 0.0079 (0.0083)  loss_rpn_box_reg: 0.0174 (0.0252)  time: 0.5928  data: 0.0061  max mem: 3656
# Epoch: [4]  [ 30/189]  eta: 0:01:37  lr: 0.000500  loss: 0.2586 (0.2560)  loss_classifier: 0.0767 (0.0793)  loss_box_reg: 0.1521 (0.1467)  loss_objectness: 0.0063 (0.0075)  loss_rpn_box_reg: 0.0133 (0.0225)  time: 0.6034  data: 0.0071  max mem: 3656
# Epoch: [4]  [ 35/189]  eta: 0:01:33  lr: 0.000500  loss: 0.2974 (0.2798)  loss_classifier: 0.0899 (0.0884)  loss_box_reg: 0.1503 (0.1517)  loss_objectness: 0.0079 (0.0094)  loss_rpn_box_reg: 0.0171 (0.0303)  time: 0.5994  data: 0.0071  max mem: 3656
# Epoch: [4]  [ 40/189]  eta: 0:01:31  lr: 0.000500  loss: 0.2997 (0.3113)  loss_classifier: 0.0943 (0.0923)  loss_box_reg: 0.1521 (0.1582)  loss_objectness: 0.0083 (0.0149)  loss_rpn_box_reg: 0.0174 (0.0460)  time: 0.6151  data: 0.0070  max mem: 3656
# Epoch: [4]  [ 45/189]  eta: 0:01:27  lr: 0.000500  loss: 0.2974 (0.3043)  loss_classifier: 0.0795 (0.0903)  loss_box_reg: 0.1364 (0.1572)  loss_objectness: 0.0072 (0.0142)  loss_rpn_box_reg: 0.0136 (0.0426)  time: 0.6064  data: 0.0073  max mem: 3656
# ...
# Epoch: [8]  [130/189]  eta: 0:00:34  lr: 0.000050  loss: 0.2605 (0.2878)  loss_classifier: 0.0845 (0.0876)  loss_box_reg: 0.1625 (0.1548)  loss_objectness: 0.0044 (0.0095)  loss_rpn_box_reg: 0.0141 (0.0359)  time: 0.5841  data: 0.0071  max mem: 3748
# Epoch: [8]  [135/189]  eta: 0:00:31  lr: 0.000050  loss: 0.2517 (0.2881)  loss_classifier: 0.0758 (0.0876)  loss_box_reg: 0.1163 (0.1559)  loss_objectness: 0.0044 (0.0093)  loss_rpn_box_reg: 0.0141 (0.0353)  time: 0.5868  data: 0.0073  max mem: 3748
# Epoch: [8]  [140/189]  eta: 0:00:28  lr: 0.000050  loss: 0.2517 (0.2867)  loss_classifier: 0.0758 (0.0873)  loss_box_reg: 0.1272 (0.1557)  loss_objectness: 0.0040 (0.0092)  loss_rpn_box_reg: 0.0155 (0.0345)  time: 0.5924  data: 0.0074  max mem: 3748
# Epoch: [8]  [145/189]  eta: 0:00:25  lr: 0.000050  loss: 0.1927 (0.2828)  loss_classifier: 0.0604 (0.0861)  loss_box_reg: 0.1140 (0.1541)  loss_objectness: 0.0024 (0.0090)  loss_rpn_box_reg: 0.0098 (0.0337)  time: 0.6053  data: 0.0073  max mem: 3748
# Epoch: [8]  [150/189]  eta: 0:00:23  lr: 0.000050  loss: 0.1927 (0.2820)  loss_classifier: 0.0604 (0.0856)  loss_box_reg: 0.1235 (0.1535)  loss_objectness: 0.0030 (0.0090)  loss_rpn_box_reg: 0.0152 (0.0339)  time: 0.5989  data: 0.0074  max mem: 3748
# Epoch: [8]  [155/189]  eta: 0:00:20  lr: 0.000050  loss: 0.2185 (0.2817)  loss_classifier: 0.0616 (0.0859)  loss_box_reg: 0.1316 (0.1537)  loss_objectness: 0.0030 (0.0089)  loss_rpn_box_reg: 0.0111 (0.0331)  time: 0.6015  data: 0.0071  max mem: 3748
# Epoch: [8]  [160/189]  eta: 0:00:17  lr: 0.000050  loss: 0.2587 (0.2813)  loss_classifier: 0.0762 (0.0857)  loss_box_reg: 0.1235 (0.1532)  loss_objectness: 0.0058 (0.0090)  loss_rpn_box_reg: 0.0117 (0.0334)  time: 0.6037  data: 0.0069  max mem: 3748
# Epoch: [8]  [165/189]  eta: 0:00:14  lr: 0.000050  loss: 0.2838 (0.2826)  loss_classifier: 0.0797 (0.0862)  loss_box_reg: 0.1686 (0.1545)  loss_objectness: 0.0069 (0.0089)  loss_rpn_box_reg: 0.0168 (0.0331)  time: 0.6004  data: 0.0069  max mem: 3748
# Epoch: [8]  [170/189]  eta: 0:00:11  lr: 0.000050  loss: 0.2827 (0.2826)  loss_classifier: 0.0786 (0.0860)  loss_box_reg: 0.1388 (0.1541)  loss_objectness: 0.0055 (0.0088)  loss_rpn_box_reg: 0.0152 (0.0338)  time: 0.6053  data: 0.0069  max mem: 3748
# Epoch: [8]  [175/189]  eta: 0:00:08  lr: 0.000050  loss: 0.2814 (0.2818)  loss_classifier: 0.0761 (0.0858)  loss_box_reg: 0.1359 (0.1538)  loss_objectness: 0.0052 (0.0087)  loss_rpn_box_reg: 0.0168 (0.0335)  time: 0.5962  data: 0.0070  max mem: 3748
# Epoch: [8]  [180/189]  eta: 0:00:05  lr: 0.000050  loss: 0.2901 (0.2842)  loss_classifier: 0.0786 (0.0866)  loss_box_reg: 0.1882 (0.1556)  loss_objectness: 0.0036 (0.0088)  loss_rpn_box_reg: 0.0168 (0.0332)  time: 0.5931  data: 0.0075  max mem: 3748
# Epoch: [8]  [185/189]  eta: 0:00:02  lr: 0.000050  loss: 0.2728 (0.2828)  loss_classifier: 0.0770 (0.0860)  loss_box_reg: 0.1683 (0.1552)  loss_objectness: 0.0036 (0.0087)  loss_rpn_box_reg: 0.0132 (0.0329)  time: 0.5884  data: 0.0074  max mem: 3748
# Epoch: [8]  [188/189]  eta: 0:00:00  lr: 0.000050  loss: 0.2991 (0.2843)  loss_classifier: 0.0877 (0.0860)  loss_box_reg: 0.1732 (0.1568)  loss_objectness: 0.0046 (0.0087)  loss_rpn_box_reg: 0.0148 (0.0328)  time: 0.5908  data: 0.0073  max mem: 3748
# Epoch: [8] Total time: 0:01:51 (0.5923 s / it)
# creating index...
# index created!
# Test:  [ 0/25]  eta: 0:00:14  model_time: 0.2904 (0.2904)  evaluator_time: 0.0044 (0.0044)  time: 0.5715  data: 0.2729  max mem: 3748
# Test:  [24/25]  eta: 0:00:00  model_time: 0.2384 (0.2498)  evaluator_time: 0.0050 (0.0067)  time: 0.2631  data: 0.0062  max mem: 3748
# Test: Total time: 0:00:06 (0.2799 s / it)
# Averaged stats: model_time: 0.2384 (0.2498)  evaluator_time: 0.0050 (0.0067)
# Accumulating evaluation results...
# DONE (t=0.03s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.471
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.788
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.494
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.280
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.516
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.383
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.167
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.572
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.604
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.306
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.617
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.617
# Epoch: [9]  [  0/189]  eta: 0:02:58  lr: 0.000005  loss: 0.0931 (0.0931)  loss_classifier: 0.0207 (0.0207)  loss_box_reg: 0.0660 (0.0660)  loss_objectness: 0.0005 (0.0005)  loss_rpn_box_reg: 0.0058 (0.0058)  time: 0.9452  data: 0.3090  max mem: 3748
# Epoch: [9]  [  5/189]  eta: 0:01:56  lr: 0.000005  loss: 0.2554 (0.2276)  loss_classifier: 0.0619 (0.0731)  loss_box_reg: 0.1028 (0.1273)  loss_objectness: 0.0024 (0.0073)  loss_rpn_box_reg: 0.0105 (0.0200)  time: 0.6351  data: 0.0585  max mem: 3748
# Epoch: [9]  [ 10/189]  eta: 0:01:47  lr: 0.000005  loss: 0.2554 (0.2243)  loss_classifier: 0.0655 (0.0735)  loss_box_reg: 0.1268 (0.1282)  loss_objectness: 0.0025 (0.0063)  loss_rpn_box_reg: 0.0113 (0.0163)  time: 0.6033  data: 0.0337  max mem: 3748
# Epoch: [9]  [ 15/189]  eta: 0:01:44  lr: 0.000005  loss: 0.2360 (0.2357)  loss_classifier: 0.0644 (0.0749)  loss_box_reg: 0.1399 (0.1355)  loss_objectness: 0.0024 (0.0067)  loss_rpn_box_reg: 0.0113 (0.0185)  time: 0.5981  data: 0.0253  max mem: 3748
# Epoch: [9]  [ 20/189]  eta: 0:01:42  lr: 0.000005  loss: 0.2414 (0.2776)  loss_classifier: 0.0711 (0.0834)  loss_box_reg: 0.1481 (0.1478)  loss_objectness: 0.0047 (0.0105)  loss_rpn_box_reg: 0.0138 (0.0359)  time: 0.5868  data: 0.0069  max mem: 3748
# Epoch: [9]  [ 25/189]  eta: 0:01:39  lr: 0.000005  loss: 0.2360 (0.2848)  loss_classifier: 0.0774 (0.0877)  loss_box_reg: 0.1481 (0.1524)  loss_objectness: 0.0029 (0.0094)  loss_rpn_box_reg: 0.0153 (0.0353)  time: 0.6010  data: 0.0067  max mem: 3751
# Epoch: [9]  [ 30/189]  eta: 0:01:35  lr: 0.000005  loss: 0.2414 (0.2931)  loss_classifier: 0.0961 (0.0896)  loss_box_reg: 0.1532 (0.1610)  loss_objectness: 0.0041 (0.0089)  loss_rpn_box_reg: 0.0169 (0.0336)  time: 0.6030  data: 0.0074  max mem: 3751
# Epoch: [9]  [ 35/189]  eta: 0:01:33  lr: 0.000005  loss: 0.2948 (0.2887)  loss_classifier: 0.1001 (0.0892)  loss_box_reg: 0.1411 (0.1595)  loss_objectness: 0.0034 (0.0082)  loss_rpn_box_reg: 0.0169 (0.0319)  time: 0.6134  data: 0.0075  max mem: 3751
# Epoch: [9]  [ 40/189]  eta: 0:01:29  lr: 0.000005  loss: 0.2591 (0.2770)  loss_classifier: 0.0889 (0.0858)  loss_box_reg: 0.1411 (0.1546)  loss_objectness: 0.0029 (0.0076)  loss_rpn_box_reg: 0.0126 (0.0290)  time: 0.6016  data: 0.0074  max mem: 3751
# Epoch: [9]  [ 45/189]  eta: 0:01:26  lr: 0.000005  loss: 0.2282 (0.2775)  loss_classifier: 0.0825 (0.0883)  loss_box_reg: 0.1395 (0.1528)  loss_objectness: 0.0034 (0.0082)  loss_rpn_box_reg: 0.0101 (0.0283)  time: 0.5939  data: 0.0076  max mem: 3751
# Epoch: [9]  [ 50/189]  eta: 0:01:23  lr: 0.000005  loss: 0.2469 (0.2798)  loss_classifier: 0.0673 (0.0877)  loss_box_reg: 0.1411 (0.1535)  loss_objectness: 0.0035 (0.0081)  loss_rpn_box_reg: 0.0106 (0.0304)  time: 0.6020  data: 0.0076  max mem: 3751
# Epoch: [9]  [ 55/189]  eta: 0:01:20  lr: 0.000005  loss: 0.2492 (0.2856)  loss_classifier: 0.0814 (0.0900)  loss_box_reg: 0.1565 (0.1577)  loss_objectness: 0.0052 (0.0080)  loss_rpn_box_reg: 0.0123 (0.0298)  time: 0.5913  data: 0.0075  max mem: 3751
# Epoch: [9]  [ 60/189]  eta: 0:01:17  lr: 0.000005  loss: 0.2558 (0.2836)  loss_classifier: 0.0814 (0.0891)  loss_box_reg: 0.1565 (0.1567)  loss_objectness: 0.0053 (0.0077)  loss_rpn_box_reg: 0.0156 (0.0301)  time: 0.5935  data: 0.0073  max mem: 3751
# Epoch: [9]  [ 65/189]  eta: 0:01:14  lr: 0.000005  loss: 0.2558 (0.2814)  loss_classifier: 0.0815 (0.0886)  loss_box_reg: 0.1534 (0.1562)  loss_objectness: 0.0053 (0.0076)  loss_rpn_box_reg: 0.0156 (0.0289)  time: 0.5933  data: 0.0074  max mem: 3751
# Epoch: [9]  [ 70/189]  eta: 0:01:11  lr: 0.000005  loss: 0.2492 (0.2788)  loss_classifier: 0.0764 (0.0887)  loss_box_reg: 0.1476 (0.1550)  loss_objectness: 0.0045 (0.0072)  loss_rpn_box_reg: 0.0155 (0.0278)  time: 0.5881  data: 0.0074  max mem: 3751
# Epoch: [9]  [ 75/189]  eta: 0:01:08  lr: 0.000005  loss: 0.2273 (0.2744)  loss_classifier: 0.0700 (0.0873)  loss_box_reg: 0.1407 (0.1537)  loss_objectness: 0.0030 (0.0069)  loss_rpn_box_reg: 0.0110 (0.0265)  time: 0.5946  data: 0.0082  max mem: 3751
# Epoch: [9]  [ 80/189]  eta: 0:01:05  lr: 0.000005  loss: 0.2273 (0.2786)  loss_classifier: 0.0700 (0.0877)  loss_box_reg: 0.1407 (0.1565)  loss_objectness: 0.0032 (0.0072)  loss_rpn_box_reg: 0.0109 (0.0272)  time: 0.5892  data: 0.0082  max mem: 3751
# Epoch: [9]  [ 85/189]  eta: 0:01:01  lr: 0.000005  loss: 0.2232 (0.2757)  loss_classifier: 0.0685 (0.0867)  loss_box_reg: 0.1307 (0.1556)  loss_objectness: 0.0020 (0.0070)  loss_rpn_box_reg: 0.0096 (0.0264)  time: 0.5833  data: 0.0078  max mem: 3751
# Epoch: [9]  [ 90/189]  eta: 0:00:58  lr: 0.000005  loss: 0.2709 (0.2734)  loss_classifier: 0.0792 (0.0861)  loss_box_reg: 0.1422 (0.1545)  loss_objectness: 0.0033 (0.0069)  loss_rpn_box_reg: 0.0096 (0.0260)  time: 0.5829  data: 0.0077  max mem: 3751
# Epoch: [9]  [ 95/189]  eta: 0:00:55  lr: 0.000005  loss: 0.2794 (0.2774)  loss_classifier: 0.0809 (0.0873)  loss_box_reg: 0.1613 (0.1554)  loss_objectness: 0.0037 (0.0069)  loss_rpn_box_reg: 0.0204 (0.0278)  time: 0.5740  data: 0.0071  max mem: 3751
# Epoch: [9]  [100/189]  eta: 0:00:52  lr: 0.000005  loss: 0.2794 (0.2769)  loss_classifier: 0.0782 (0.0868)  loss_box_reg: 0.1422 (0.1549)  loss_objectness: 0.0037 (0.0070)  loss_rpn_box_reg: 0.0150 (0.0282)  time: 0.5862  data: 0.0072  max mem: 3751
# Epoch: [9]  [105/189]  eta: 0:00:50  lr: 0.000005  loss: 0.2732 (0.2748)  loss_classifier: 0.0782 (0.0862)  loss_box_reg: 0.1422 (0.1543)  loss_objectness: 0.0055 (0.0070)  loss_rpn_box_reg: 0.0142 (0.0273)  time: 0.5943  data: 0.0072  max mem: 3751
# Epoch: [9]  [110/189]  eta: 0:00:46  lr: 0.000005  loss: 0.2221 (0.2719)  loss_classifier: 0.0642 (0.0852)  loss_box_reg: 0.1197 (0.1529)  loss_objectness: 0.0061 (0.0070)  loss_rpn_box_reg: 0.0160 (0.0268)  time: 0.5895  data: 0.0073  max mem: 3751
# Epoch: [9]  [115/189]  eta: 0:00:43  lr: 0.000005  loss: 0.2194 (0.2750)  loss_classifier: 0.0642 (0.0868)  loss_box_reg: 0.1136 (0.1520)  loss_objectness: 0.0058 (0.0073)  loss_rpn_box_reg: 0.0142 (0.0289)  time: 0.5852  data: 0.0071  max mem: 3751
# Epoch: [9]  [120/189]  eta: 0:00:40  lr: 0.000005  loss: 0.2072 (0.2737)  loss_classifier: 0.0642 (0.0861)  loss_box_reg: 0.1136 (0.1515)  loss_objectness: 0.0058 (0.0071)  loss_rpn_box_reg: 0.0142 (0.0290)  time: 0.5767  data: 0.0071  max mem: 3751
# Epoch: [9]  [125/189]  eta: 0:00:37  lr: 0.000005  loss: 0.2365 (0.2746)  loss_classifier: 0.0761 (0.0864)  loss_box_reg: 0.1136 (0.1518)  loss_objectness: 0.0052 (0.0072)  loss_rpn_box_reg: 0.0160 (0.0293)  time: 0.5668  data: 0.0071  max mem: 3751
# Epoch: [9]  [130/189]  eta: 0:00:34  lr: 0.000005  loss: 0.2742 (0.2752)  loss_classifier: 0.0801 (0.0864)  loss_box_reg: 0.1455 (0.1524)  loss_objectness: 0.0052 (0.0072)  loss_rpn_box_reg: 0.0157 (0.0293)  time: 0.5719  data: 0.0070  max mem: 3751
# Epoch: [9]  [135/189]  eta: 0:00:31  lr: 0.000005  loss: 0.3084 (0.2809)  loss_classifier: 0.0934 (0.0885)  loss_box_reg: 0.1714 (0.1551)  loss_objectness: 0.0058 (0.0076)  loss_rpn_box_reg: 0.0221 (0.0297)  time: 0.5820  data: 0.0072  max mem: 3751
# Epoch: [9]  [140/189]  eta: 0:00:28  lr: 0.000005  loss: 0.3014 (0.2778)  loss_classifier: 0.0933 (0.0873)  loss_box_reg: 0.1653 (0.1538)  loss_objectness: 0.0058 (0.0075)  loss_rpn_box_reg: 0.0201 (0.0292)  time: 0.5845  data: 0.0073  max mem: 3751
# Epoch: [9]  [145/189]  eta: 0:00:25  lr: 0.000005  loss: 0.2993 (0.2771)  loss_classifier: 0.0801 (0.0868)  loss_box_reg: 0.1543 (0.1531)  loss_objectness: 0.0056 (0.0075)  loss_rpn_box_reg: 0.0159 (0.0297)  time: 0.5839  data: 0.0073  max mem: 3751
# Epoch: [9]  [150/189]  eta: 0:00:23  lr: 0.000005  loss: 0.2973 (0.2794)  loss_classifier: 0.0947 (0.0874)  loss_box_reg: 0.1543 (0.1547)  loss_objectness: 0.0058 (0.0076)  loss_rpn_box_reg: 0.0160 (0.0297)  time: 0.5867  data: 0.0072  max mem: 3751
# Epoch: [9]  [155/189]  eta: 0:00:20  lr: 0.000005  loss: 0.2497 (0.2840)  loss_classifier: 0.0691 (0.0872)  loss_box_reg: 0.1518 (0.1546)  loss_objectness: 0.0054 (0.0086)  loss_rpn_box_reg: 0.0159 (0.0337)  time: 0.5861  data: 0.0071  max mem: 3751
# Epoch: [9]  [160/189]  eta: 0:00:17  lr: 0.000005  loss: 0.2677 (0.2822)  loss_classifier: 0.0840 (0.0865)  loss_box_reg: 0.1543 (0.1535)  loss_objectness: 0.0073 (0.0086)  loss_rpn_box_reg: 0.0195 (0.0335)  time: 0.5918  data: 0.0072  max mem: 3751
# Epoch: [9]  [165/189]  eta: 0:00:14  lr: 0.000005  loss: 0.2973 (0.2839)  loss_classifier: 0.0859 (0.0870)  loss_box_reg: 0.1643 (0.1543)  loss_objectness: 0.0073 (0.0086)  loss_rpn_box_reg: 0.0257 (0.0340)  time: 0.5921  data: 0.0072  max mem: 3751
# Epoch: [9]  [170/189]  eta: 0:00:11  lr: 0.000005  loss: 0.2677 (0.2834)  loss_classifier: 0.0840 (0.0864)  loss_box_reg: 0.1498 (0.1542)  loss_objectness: 0.0073 (0.0086)  loss_rpn_box_reg: 0.0218 (0.0342)  time: 0.5934  data: 0.0074  max mem: 3751
# Epoch: [9]  [175/189]  eta: 0:00:08  lr: 0.000005  loss: 0.2864 (0.2844)  loss_classifier: 0.0942 (0.0869)  loss_box_reg: 0.1464 (0.1546)  loss_objectness: 0.0070 (0.0085)  loss_rpn_box_reg: 0.0218 (0.0345)  time: 0.5918  data: 0.0073  max mem: 3751
# Epoch: [9]  [180/189]  eta: 0:00:05  lr: 0.000005  loss: 0.3385 (0.2849)  loss_classifier: 0.0967 (0.0870)  loss_box_reg: 0.1574 (0.1554)  loss_objectness: 0.0044 (0.0084)  loss_rpn_box_reg: 0.0218 (0.0341)  time: 0.5808  data: 0.0070  max mem: 3751
# Epoch: [9]  [185/189]  eta: 0:00:02  lr: 0.000005  loss: 0.2902 (0.2834)  loss_classifier: 0.0942 (0.0866)  loss_box_reg: 0.1464 (0.1549)  loss_objectness: 0.0043 (0.0083)  loss_rpn_box_reg: 0.0167 (0.0335)  time: 0.6064  data: 0.0071  max mem: 3751
# Epoch: [9]  [188/189]  eta: 0:00:00  lr: 0.000005  loss: 0.2902 (0.2835)  loss_classifier: 0.0901 (0.0866)  loss_box_reg: 0.1574 (0.1555)  loss_objectness: 0.0047 (0.0083)  loss_rpn_box_reg: 0.0143 (0.0332)  time: 0.5980  data: 0.0069  max mem: 3751
# Epoch: [9] Total time: 0:01:51 (0.5922 s / it)
# creating index...
# index created!
# Test:  [ 0/25]  eta: 0:00:14  model_time: 0.2995 (0.2995)  evaluator_time: 0.0043 (0.0043)  time: 0.5956  data: 0.2883  max mem: 3751
# Test:  [24/25]  eta: 0:00:00  model_time: 0.2387 (0.2499)  evaluator_time: 0.0050 (0.0069)  time: 0.2629  data: 0.0058  max mem: 3751
# Test: Total time: 0:00:07 (0.2806 s / it)
# Averaged stats: model_time: 0.2387 (0.2499)  evaluator_time: 0.0050 (0.0069)
# Accumulating evaluation results...
# DONE (t=0.03s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.470
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.788
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.495
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.280
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.515
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.383
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.167
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.572
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.603
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.306
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.616
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.617

# %%
PATH = "/content/drive/MyDrive/EE626_Project/Detection_model/detection_faster_rcnn.pth"
torch.save(model, PATH)
